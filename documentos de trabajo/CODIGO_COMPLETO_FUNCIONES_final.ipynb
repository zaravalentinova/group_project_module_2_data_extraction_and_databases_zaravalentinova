# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import requests
import csv
import re
import mysql.connector 

# Configuración
CLIENT_ID = '9189e74191a848bf82c60efbf06229c6'
CLIENT_SECRET = '36c5b1edfa3744e7ac992361fa2b5b02'
API_KEY_LASTFM = '472626d71b58f9fbdd11821189cb8716'
BASE_URL = "http://ws.audioscrobbler.com/2.0/"

# Configuración MySQL
DB_CONFIG = {
    'user': 'root',
    'password': 'AlumnaAdalab',
    'host': '127.0.0.1',
    'database': 'proyecto_grupal_mod_2'
}

# Función 1: Conectar con Spotify
def conectar_spotify():
    
    sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
        client_id=CLIENT_ID,
        client_secret=CLIENT_SECRET
    ))
    return sp

# Función 2: Buscar canciones de un género y año
def buscar_canciones(sp, genero, ano):
    
    canciones = []
    
    # Buscar en dos páginas (0 y 50)
    for pagina in [0, 50]:
        resultados = sp.search(q=f'genre:"{genero}" year:{ano}', 
                              type='track', 
                              limit=50, 
                              offset=pagina)
        
        # Procesar tracks:
        for cancion in resultados['tracks']['items']:
            # Obtener nombres de artistas
            artistas = []
            for artista in cancion['artists']:
                artistas.append(artista['name'])
            
            # Crear diccionario con datos de la canción
            datos_cancion = {
                'artistas': ', '.join(artistas),
                'colaboracion': len(artistas) > 1,
                'genero_musical': genero,
                'nombre': cancion['name'],
                'ano_lanzamiento': cancion['album']['release_date'][:4],
                'id': cancion['id'],
                'tipo': 'track'
                }
           
            canciones.append(datos_cancion)

    return canciones

# Función 3: Obtener todas las canciones
def obtener_todas_canciones():
    
    # Conectar con Spotify
    sp = conectar_spotify()
    
    # Listas de géneros y años
    generos = ['pop', 'metal', 'reggaeton', 'rap']
    años = [2015, 2016]
    
    # Lista para guardar todas las canciones
    todas_canciones = []
    
    # Buscar canciones para cada género y año
    for genero in generos:
        print(f"Buscando tracks de {genero}...")
        for ano in años:
            print(f"  Año {ano}...")
            canciones = buscar_canciones(sp, genero, ano)
            todas_canciones.extend(canciones)
    
    return todas_canciones

# Función 4: Guardar canciones en CSV
def guardar_canciones_csv(canciones):
    
    with open('spotify_datos.csv', 'w', newline='', encoding='utf-8') as archivo:
        campos = ['artistas', 'colaboracion', 'genero_musical', 'nombre', 'ano_lanzamiento', 'id', 'tipo']
        escritor = csv.DictWriter(archivo, fieldnames=campos)
        escritor.writeheader()
        escritor.writerows(canciones)
    
    print(f"✅ Guardado: spotify_datos.csv ({len(canciones)} canciones)")

# Función 5: Leer artistas del CSV
def leer_artistas_csv():
    
    df = pd.read_csv('spotify_datos.csv')
    
    # Lista para todos los artistas
    todos_artistas = []
    
    # Procesar cada fila
    for fila in df['artistas']:
        # Separar artistas por comas
        lista_artistas = fila.split(',')
        for artista in lista_artistas:
            artista_limpio = artista.strip()  # Quitar espacios
            if artista_limpio:  # Si no está vacío
                todos_artistas.append(artista_limpio)
    
    # Quitar duplicados y ordenar
    artistas_unicos = list(set(todos_artistas))
    artistas_unicos.sort()
    
    print(f"Artistas únicos encontrados: {len(artistas_unicos)}")
    return artistas_unicos

# Función 6: Quitar etiquetas HTML
def quitar_html(texto):
    
    if texto:
        texto_limpio = re.sub('<[^<]+?>', '', texto)
        return texto_limpio.strip()
    return ''

# Función 7: Buscar información de un artista en Last.fm
def buscar_artista_lastfm(nombre_artista):
    
    # Parámetros para la API
    parametros = {
        "method": "artist.getInfo",
        "artist": nombre_artista,
        "api_key": API_KEY_LASTFM,
        "format": "json",
        "lang": "es"
    }
    
    # Hacer petición a la API
    respuesta = requests.get(BASE_URL, params=parametros)
    datos = respuesta.json()
    
    # Verificar si encontró el artista
    if "artist" in datos:
        artista_info = datos['artist']
        
        # Obtener biografía
        biografia = ''
        if 'bio' in artista_info and 'content' in artista_info['bio']:
            biografia = quitar_html(artista_info['bio']['content'])
        
        # Obtener estadísticas
        playcount = 0
        oyentes = 0
        if 'stats' in artista_info:
            playcount = artista_info['stats'].get('playcount', 0)
            oyentes = artista_info['stats'].get('listeners', 0)
        
        # Obtener artistas similares
        similares = []
        if 'similar' in artista_info and 'artist' in artista_info['similar']:
            for similar in artista_info['similar']['artist']:
                similares.append(similar.get('name', ''))
        
        # Crear diccionario con la información
        info_artista = {
            'artist': nombre_artista,
            'biografia': biografia,
            'playcount': playcount,
            'oyentes': oyentes,
            'similares': ', '.join(similares)
        }
        
        return info_artista
    
    return None

# Función 8: Obtener información de todos los artistas
def obtener_info_artistas():
    
    # Leer artistas del CSV
    artistas = leer_artistas_csv()
    
    # Lista para guardar información de artistas
    info_artistas = []
    
    # Buscar información de cada artista
    contador = 0
    for artista in artistas:
        contador += 1
        print(f"Procesando artista {contador}/{len(artistas)}: {artista}")
        
        info = buscar_artista_lastfm(artista)
        if info:
            info_artistas.append(info)
    
    return info_artistas

# Función 9: Guardar información de artistas en CSV
def guardar_artistas_csv(info_artistas):
    
    with open('lastfm_datos.csv', 'w', newline='', encoding='utf-8') as archivo:
        campos = ['artist', 'biografia', 'playcount', 'oyentes', 'similares']
        escritor = csv.DictWriter(archivo, fieldnames=campos)
        escritor.writeheader()
        escritor.writerows(info_artistas)
    
    print(f"✅ Guardado: lastfm_datos.csv ({len(info_artistas)} artistas)")

# Función 10: Proceso completo de Spotify
def proceso_spotify():
    
    print("🎵 Iniciando proceso de Spotify...")
    
    # Obtener canciones
    canciones = obtener_todas_canciones()
    
    # Guardar en CSV
    guardar_canciones_csv(canciones)
    
    print("✅ Proceso de Spotify completado")

# Función 11: Proceso completo de Last.fm
def proceso_lastfm():
    
    print("🎤 Iniciando proceso de Last.fm...")
    
    # Obtener información de artistas
    info_artistas = obtener_info_artistas()
    
    # Guardar en CSV
    guardar_artistas_csv(info_artistas)
    
    print("✅ Proceso de Last.fm completado")

# Función 12: Proceso completo
def proceso_completo():
    
    print("🚀 Iniciando proceso completo...")
    
    # Primero Spotify
    proceso_spotify()
    
    # Luego Last.fm
    proceso_lastfm()
    
    print("✅ ¡Todo terminado!")

# Función 13: Conectar con MySQL
def conectar_mysql():
    
    print("🔗 Conectando con MySQL...")
    
    cnx = mysql.connector.connect(**DB_CONFIG)
    print("✅ Conexión establecida:", cnx)
    
    # Verificar base de datos activa
    mycursor = cnx.cursor()
    mycursor.execute("SELECT DATABASE();")
    db_actual = mycursor.fetchone()
    print("Base de datos activa:", db_actual)
    mycursor.close()
    
    return cnx

# Función 14: Insertar artistas en MySQL
def insertar_artistas_mysql():
    
    print("🎤 Insertando artistas en MySQL...")
    
    # Conectar con MySQL
    cnx = conectar_mysql()
    mycursor = cnx.cursor()
    
    # Leer archivo CSV
    with open('lastfm_datos.csv', 'r', encoding='utf-8') as archivo_csv:
        reader = csv.DictReader(archivo_csv)
        
        for fila in reader:
            sql = """
                INSERT INTO artistas (nombre, biografia, playcount, oyentes, similares)
                VALUES (%s, %s, %s, %s, %s)
                ON DUPLICATE KEY UPDATE 
                    biografia = VALUES(biografia),
                    playcount = VALUES(playcount),
                    oyentes = VALUES(oyentes),
                    similares = VALUES(similares)
            """
            
            valores = (
                fila['artist'],
                fila['biografia'],
                int(fila['playcount']),
                int(fila['oyentes']),
                fila.get('similares', '')
            )
            
            mycursor.execute(sql, valores)
    
    # Guardar cambios
    cnx.commit()
    mycursor.close()
    cnx.close()
    
    print("✅ Artistas insertados en MySQL correctamente")

# Función 15: Insertar canciones en MySQL
def insertar_canciones_mysql():
    
    print("🎵 Insertando canciones en MySQL...")
    
    # Conectar con MySQL
    cnx = conectar_mysql()
    mycursor = cnx.cursor()
    
    # Leer archivo CSV
    with open('spotify_datos.csv', 'r', encoding='utf-8') as archivo_csv:
        reader = csv.DictReader(archivo_csv)
        
        for fila in reader:
            # 1. Insertar canción
            sql_cancion = """
                INSERT INTO canciones (nombre, genero_musical, tipo, año_lanzamiento, id_spotify)
                VALUES (%s, %s, %s, %s, %s)
                ON DUPLICATE KEY UPDATE nombre = VALUES(nombre)
            """
            
            valores_cancion = (
                fila['nombre'],
                fila['genero_musical'],
                fila['tipo'],
                int(fila['ano_lanzamiento']),
                fila['id']
            )
            
            mycursor.execute(sql_cancion, valores_cancion)
            
            # 2. Obtener ID de la canción
            mycursor.execute("SELECT id_cancion FROM canciones WHERE id_spotify = %s", (fila['id'],))
            id_cancion = mycursor.fetchone()[0]
            
            # 3. Insertar relación canción-artista
            artistas = [art.strip() for art in fila['artistas'].split(',')]
            for artista in artistas:
                # Buscar ID del artista
                mycursor.execute("SELECT id_artista FROM artistas WHERE nombre COLLATE utf8mb4_general_ci = %s", (artista,))
                res = mycursor.fetchone()
                
                if res:
                    id_artista = res[0]
                    sql_relacion = """
                        INSERT INTO canciones_artistas (id_cancion, id_artista)
                        VALUES (%s, %s)
                        ON DUPLICATE KEY UPDATE id_cancion = id_cancion
                    """
                    mycursor.execute(sql_relacion, (id_cancion, id_artista))
    
    # Guardar cambios
    cnx.commit()
    mycursor.close()
    cnx.close()
    
    print("✅ Canciones insertadas en MySQL correctamente")

# Función 16: Insertar todos los datos en MySQL
def insertar_datos_mysql():
    
    print("💾 Insertando todos los datos en MySQL...")
    
    # Primero insertar artistas
    insertar_artistas_mysql()
    
    # Luego insertar canciones
    insertar_canciones_mysql()
    
    print("✅ Todos los datos insertados en MySQL")

# Función 17: Proceso completo con MySQL
def proceso_completo_mysql():
    
    print("🚀 Iniciando proceso completo con MySQL...")
    
    # 1. Proceso de Spotify
    proceso_spotify()
    
    # 2. Proceso de Last.fm
    proceso_lastfm()
    
    # 3. Insertar en MySQL
    insertar_datos_mysql()
    
    print("✅ ¡Todo terminado con MySQL!")

# Función 18: Solo MySQL (solo inserta los datos si ya tienes los CSV)
def solo_mysql():
    
    print("💾 Insertando datos existentes en MySQL...")
    insertar_datos_mysql()

# Ejecutar el programa
if __name__ == "__main__":
    # Opción 1: Proceso completo con MySQL
    proceso_completo_mysql()
    
    # Opción 2: Solo MySQL (descomenta la línea siguiente)
# Out:
# 🚀 Iniciando proceso completo con MySQL...
# 🎵 Iniciando proceso de Spotify...
# Buscando tracks de pop...
#   Año 2015...
#   Año 2016...
# Buscando tracks de metal...
#   Año 2015...
#   Año 2016...
# Buscando tracks de reggaeton...
#   Año 2015...
#   Año 2016...
# Buscando tracks de rap...
#   Año 2015...
#   Año 2016...
# ✅ Guardado: spotify_datos.csv (800 canciones)
# ✅ Proceso de Spotify completado
# 🎤 Iniciando proceso de Last.fm...
# Artistas únicos encontrados: 824
# Procesando artista 1/824: 20 Grand
# Procesando artista 2/824: 2Edge
# Procesando artista 3/824: 46Simmy
# Procesando artista 4/824: 5th Ward JP
# Procesando artista 5/824: 679
# Procesando artista 6/824: 7 H. Target
# Procesando artista 7/824: 88 Killa
# Procesando artista 8/824: 8Ball & MJG
# Procesando artista 9/824: 8m/s
# Procesando artista 10/824: A Dream Of Poe
# Procesando artista 11/824: Abandoned Elysium
# Procesando artista 12/824: Abraham Mateo
# Procesando artista 13/824: Ace Wonda
# Procesando artista 14/824: Acid Death
# Procesando artista 15/824: Adnan Sami
# Procesando artista 16/824: Afrigo Band
# Procesando artista 17/824: Aggronymph
# Procesando artista 18/824: Agnaldo Timoteo
# Procesando artista 19/824: Agonal
# Procesando artista 20/824: Agregator
# Procesando artista 21/824: Akem Manah
# Procesando artista 22/824: Akribi
# Procesando artista 23/824: Alam Lohar
# Procesando artista 24/824: Alaza
# Procesando artista 25/824: Alex Martinho
# Procesando artista 26/824: Alexander DJ
# Procesando artista 27/824: Alexander Popov
# Procesando artista 28/824: Alfredo Sadel
# Procesando artista 29/824: Ali Jr
# Procesando artista 30/824: Alienadept
# Procesando artista 31/824: Alkawi
# Procesando artista 32/824: Alla Pugacheva
# Procesando artista 33/824: Amado Tovar
# Procesando artista 34/824: Amaro
# Procesando artista 35/824: Amaro.
# Procesando artista 36/824: Amir Naser Eftetah
# Procesando artista 37/824: Analiza Slim
# Procesando artista 38/824: Anders F. Rönnblom
# Procesando artista 39/824: Andrew Rayel
# Procesando artista 40/824: Andy Boy
# Procesando artista 41/824: Andy G
# Procesando artista 42/824: Anfuse
# Procesando artista 43/824: Angel & Ranking
# Procesando artista 44/824: Angel 7
# Procesando artista 45/824: Angel Doze
# Procesando artista 46/824: Animality
# Procesando artista 47/824: Antoine Henaut
# Procesando artista 48/824: Apathy
# Procesando artista 49/824: Ape Machine
# Procesando artista 50/824: Aran One
# Procesando artista 51/824: Archetype
# Procesando artista 52/824: Are el Real
# Procesando artista 53/824: Argos
# Procesando artista 54/824: Arianna Puello
# Procesando artista 55/824: Arjan Korkaj
# Procesando artista 56/824: Armin van Buuren
# Procesando artista 57/824: Arrhythmia
# Procesando artista 58/824: Arsenal
# Procesando artista 59/824: Arsonal da Rebel
# Procesando artista 60/824: Artista Rosario
# Procesando artista 61/824: Aryon
# Procesando artista 62/824: As Darkness Fell
# Procesando artista 63/824: Asgrauw
# Procesando artista 64/824: Asha Vaishnav
# Procesando artista 65/824: Audiotree
# Procesando artista 66/824: Autoescuela
# Procesando artista 67/824: Autolatry
# Procesando artista 68/824: Avitas
# Procesando artista 69/824: Awakened Inferno
# Procesando artista 70/824: Aye Mammoth
# Procesando artista 71/824: Aylu
# Procesando artista 72/824: Aziatic
# Procesando artista 73/824: Azorap
# Procesando artista 74/824: BADSISTA
# Procesando artista 75/824: Baboon Rising
# Procesando artista 76/824: Baby Gas
# Procesando artista 77/824: Baby Naznin
# Procesando artista 78/824: Baby Noel
# Procesando artista 79/824: Bako
# Procesando artista 80/824: BandGang
# Procesando artista 81/824: Beat Punches
# Procesando artista 82/824: BeatBoy
# Procesando artista 83/824: Beeda Weeda
# Procesando artista 84/824: Before the Foundation
# Procesando artista 85/824: Beltito "Esta En El Beat"
# Procesando artista 86/824: Benny Benni
# Procesando artista 87/824: Bernatchez
# Procesando artista 88/824: Best 4 Ever
# Procesando artista 89/824: Big Boy
# Procesando artista 90/824: Biggs da C.E.O.
# Procesando artista 91/824: Biglightbeatz
# Procesando artista 92/824: Bill Collector
# Procesando artista 93/824: Bing
# Procesando artista 94/824: Biznaga
# Procesando artista 95/824: Black Boy
# Procesando artista 96/824: Black Hate
# Procesando artista 97/824: Black Mikey
# Procesando artista 98/824: Black Soprano Family
# Procesando artista 99/824: Blacksoul Seraphim
# Procesando artista 100/824: Blacktooth
# Procesando artista 101/824: Bloodphemy
# Procesando artista 102/824: Bloody Hell
# Procesando artista 103/824: Bokun
# Procesando artista 104/824: Bone Thugs-N-Harmony
# Procesando artista 105/824: Boo Banga
# Procesando artista 106/824: Booz
# Procesando artista 107/824: Box
# Procesando artista 108/824: Bq tha Emcee
# Procesando artista 109/824: Breno Ruiz
# Procesando artista 110/824: Brytiago
# Procesando artista 111/824: Bunbury
# Procesando artista 112/824: Bundo
# Procesando artista 113/824: Buxxi
# Procesando artista 114/824: By Will Alone
# Procesando artista 115/824: C.M.L.
# Procesando artista 116/824: CD9
# Procesando artista 117/824: CHIKA ANDRIYANI
# Procesando artista 118/824: COSMOSTOM
# Procesando artista 119/824: CRAM
# Procesando artista 120/824: CTS
# Procesando artista 121/824: CTS Kamika-Z
# Procesando artista 122/824: Caitlin Hart
# Procesando artista 123/824: Calamity
# Procesando artista 124/824: Camileazy
# Procesando artista 125/824: Carlito
# Procesando artista 126/824: Carnalation
# Procesando artista 127/824: Carol Nazareth
# Procesando artista 128/824: Carola
# Procesando artista 129/824: Cauê
# Procesando artista 130/824: Cell 9
# Procesando artista 131/824: Celtic Thunder
# Procesando artista 132/824: Chacal Men
# Procesando artista 133/824: Chance Capone
# Procesando artista 134/824: Chaos Descent
# Procesando artista 135/824: Char
# Procesando artista 136/824: Charly Humos
# Procesando artista 137/824: Charry Slow
# Procesando artista 138/824: Chase the Ace
# Procesando artista 139/824: Cheka
# Procesando artista 140/824: Cheka Katenen Dioubate
# Procesando artista 141/824: Cherezade
# Procesando artista 142/824: Chillin
# Procesando artista 143/824: Chino & Nacho
# Procesando artista 144/824: Chojiii
# Procesando artista 145/824: Chostin
# Procesando artista 146/824: Chris Ward
# Procesando artista 147/824: Christian Cat
# Procesando artista 148/824: Christian Liebeskind
# Procesando artista 149/824: Christof Kurzmann
# Procesando artista 150/824: Christoffer Lauridsen
# Procesando artista 151/824: Classic Noise
# Procesando artista 152/824: Coldness
# Procesando artista 153/824: Condescension
# Procesando artista 154/824: Conejo
# Procesando artista 155/824: Conor
# Procesando artista 156/824: Corey Joseph
# Procesando artista 157/824: Cousin
# Procesando artista 158/824: Cricet
# Procesando artista 159/824: Cristóbal Jiménez
# Procesando artista 160/824: Crucifer
# Procesando artista 161/824: Crumbling Ghost
# Procesando artista 162/824: Cruscifire
# Procesando artista 163/824: Cupid's Carnival
# Procesando artista 164/824: Curtis Mayz
# Procesando artista 165/824: Cyborg AOS
# Procesando artista 166/824: Cymarshall Law
# Procesando artista 167/824: Cymothoa
# Procesando artista 168/824: D'Shon El Villano
# Procesando artista 169/824: D-Baby
# Procesando artista 170/824: D.Cure
# Procesando artista 171/824: DB Tha General
# Procesando artista 172/824: DJ Kadel
# Procesando artista 173/824: DJ Memo
# Procesando artista 174/824: DJ Nelson
# Procesando artista 175/824: DMEI
# Procesando artista 176/824: Daddy Yankee
# Procesando artista 177/824: Dalibor Brun
# Procesando artista 178/824: Damien Jurado
# Procesando artista 179/824: Dan Evans
# Procesando artista 180/824: Daniel Bezzina
# Procesando artista 181/824: Daniel Huen
# Procesando artista 182/824: Daniel Marinakis
# Procesando artista 183/824: Danny Fresh
# Procesando artista 184/824: Darell
# Procesando artista 185/824: Dark Slumber
# Procesando artista 186/824: Darom Dabro
# Procesando artista 187/824: Dasoul
# Procesando artista 188/824: Dat Boi T
# Procesando artista 189/824: Datcha Dollar'z
# Procesando artista 190/824: Dave Pell
# Procesando artista 191/824: David Barrull
# Procesando artista 192/824: David Ramirez
# Procesando artista 193/824: David Vassalotti
# Procesando artista 194/824: Davonta
# Procesando artista 195/824: De Uno En Uno
# Procesando artista 196/824: Dead Eye Zack
# Procesando artista 197/824: Deadly
# Procesando artista 198/824: Decimate
# Procesando artista 199/824: Deconstructing Sequence
# Procesando artista 200/824: Devak24
# Procesando artista 201/824: Devlsy
# Procesando artista 202/824: Dexter Fizz
# Procesando artista 203/824: Dexys Midnight Runners
# Procesando artista 204/824: Diana Navarro
# Procesando artista 205/824: Diego Zamboni
# Procesando artista 206/824: Disloyal
# Procesando artista 207/824: Dispellment
# Procesando artista 208/824: Dissecdead
# Procesando artista 368/824: Jhef
# Procesando artista 369/824: Jhonedy Bs
# Procesando artista 370/824: Jiggy Drama
# Procesando artista 371/824: Jignesh Barot
# Procesando artista 372/824: Jignesh Kaviraj
# Procesando artista 373/824: Jike Junyi
# Procesando artista 374/824: Jim Markus
# Procesando artista 375/824: Jin Sunghyuk
# Procesando artista 376/824: Jireh
# Procesando artista 377/824: Joe Marro
# Procesando artista 378/824: Joel
# Procesando artista 379/824: Johan Kim
# Procesando artista 380/824: John Hidalgo
# Procesando artista 381/824: Johnny Summers
# Procesando artista 382/824: Jonny S
# Procesando artista 383/824: Joseph A. Peragine
# Procesando artista 384/824: João Gustavo e Murilo
# Procesando artista 385/824: Json
# Procesando artista 386/824: Juan Perro
# Procesando artista 387/824: Juanchu
# Procesando artista 388/824: Juanka
# Procesando artista 389/824: Julillo
# Procesando artista 390/824: Junky Zice
# Procesando artista 391/824: Juno "The Hitmaker"
# Procesando artista 392/824: Jutha & Small
# Procesando artista 393/824: Juventud Juché
# Procesando artista 394/824: K-Dee
# Procesando artista 395/824: KARWAN XABATI
# Procesando artista 396/824: KOHH
# Procesando artista 397/824: KSHMR
# Procesando artista 398/824: Kaines
# Procesando artista 399/824: Kalpana Patowary
# Procesando artista 400/824: Kangal
# Procesando artista 401/824: Kapataz
# Procesando artista 402/824: Karel Vlach se svým orchestrem
# Procesando artista 403/824: Kashflowtoofab
# Procesando artista 404/824: Kate Ryan
# Procesando artista 405/824: Kavelo Y No Drama
# Procesando artista 406/824: Keishal
# Procesando artista 407/824: Kevin Rowland
# Procesando artista 408/824: Khepri
# Procesando artista 409/824: Khesari Lal Yadav
# Procesando artista 410/824: Kholebeatz
# Procesando artista 411/824: Khushboo Jain
# Procesando artista 412/824: Kiko y Shara
# Procesando artista 413/824: Kim Marques
# Procesando artista 414/824: Kinjal Dave
# Procesando artista 415/824: Kirtidan Gadhvi
# Procesando artista 416/824: Klish
# Procesando artista 417/824: Kottonmouth Jesse
# Procesando artista 418/824: Kriler
# Procesando artista 419/824: Krishnaraj
# Procesando artista 420/824: Kronos Resistor
# Procesando artista 421/824: Kt Foreign
# Procesando artista 422/824: Kyle Rapps
# Procesando artista 423/824: L'Hexaler
# Procesando artista 424/824: L.A Hip Hop
# Procesando artista 425/824: La Barbería Del Sur
# Procesando artista 426/824: La Octava Nota
# Procesando artista 427/824: La Pols i l'Era
# Procesando artista 428/824: Lalitya Munshaw
# Procesando artista 429/824: Lapsus Dei
# Procesando artista 430/824: Larva
# Procesando artista 431/824: Las Aves Cantoras
# Procesando artista 432/824: Lasai
# Procesando artista 433/824: Latina Sativa
# Procesando artista 434/824: Lawrence P Dsouza
# Procesando artista 435/824: Leandro Solano
# Procesando artista 436/824: Leni Alfin
# Procesando artista 437/824: Lennox
# Procesando artista 438/824: Lenny Tavárez
# Procesando artista 439/824: Leoben Conoy
# Procesando artista 440/824: Lepai
# Procesando artista 441/824: Lessa Gustavo
# Procesando artista 442/824: Lethal
# Procesando artista 443/824: Liar Symphony
# Procesando artista 444/824: Lida Husik
# Procesando artista 525/824: N.E.S
# Procesando artista 526/824: NMB48
# Procesando artista 527/824: Nagendra Ujala
# Procesando artista 528/824: Naseebo Lal
# Procesando artista 529/824: Nazia Iqbal
# Procesando artista 530/824: Ndee Naldinho
# Procesando artista 531/824: Necroticus
# Procesando artista 532/824: Neel Akash
# Procesando artista 533/824: Neleonard
# Procesando artista 534/824: Nelu Vlad
# Procesando artista 535/824: Nene Marti
# Procesando artista 536/824: Neno Calvin
# Procesando artista 537/824: Neter
# Procesando artista 538/824: Neural Fx
# Procesando artista 539/824: NeverAlone
# Procesando artista 540/824: Niche
# Procesando artista 541/824: Nick Jonas
# Procesando artista 542/824: Nicko Altain
# Procesando artista 543/824: Nicky Jam
# Procesando artista 544/824: Nicky Romero
# Procesando artista 545/824: Nilakshi Neog
# Procesando artista 546/824: Nina Badric
# Procesando artista 547/824: Niños Mutantes
# Procesando artista 548/824: Noor Jehan
# Procesando artista 549/824: Nora Brockstedt
# Procesando artista 550/824: Nova
# Procesando artista 551/824: Nuestroctubre
# Procesando artista 552/824: OG Ron C
# Procesando artista 553/824: OJM
# Procesando artista 554/824: OLD LRRD
# Procesando artista 555/824: OST
# Procesando artista 556/824: Obrero
# Procesando artista 557/824: Octalux
# Procesando artista 558/824: Oddó
# Procesando artista 559/824: Odinfist
# Procesando artista 560/824: Og Black
# Procesando artista 561/824: Oma 206
# Procesando artista 562/824: Omega Vibe
# Procesando artista 563/824: Oncology
# Procesando artista 564/824: OnellFlow
# Procesando artista 565/824: Opus V84
# Procesando artista 566/824: Order of Leviathan
# Procesando artista 567/824: Orlando Dias
# Procesando artista 568/824: Oscarcito
# Procesando artista 569/824: Outer Vibe
# Procesando artista 570/824: Outloud
# Procesando artista 571/824: Pablo Und Destruktion
# Procesando artista 572/824: Palace of Worms
# Procesando artista 573/824: Palha d'Aço
# Procesando artista 574/824: Panda Transport
# Procesando artista 575/824: Paramba
# Procesando artista 576/824: Patron
# Procesando artista 577/824: Paul Wall
# Procesando artista 578/824: Pawan Roy
# Procesando artista 579/824: Pawan Singh
# Procesando artista 580/824: Payaso
# Procesando artista 581/824: Peculate
# Procesando artista 582/824: Perreke
# Procesando artista 583/824: Phased
# Procesando artista 584/824: Phaser
# Procesando artista 585/824: Philippe Katerine
# Procesando artista 586/824: Philthy Rich
# Procesando artista 587/824: Picco
# Procesando artista 588/824: Piraña
# Procesando artista 589/824: Pistol
# Procesando artista 590/824: Plies
# Procesando artista 591/824: Poesia Letal
# Procesando artista 592/824: Pooh Rida Pirate Gang
# Procesando artista 593/824: Prajoth Dsa
# Procesando artista 594/824: Prakash Mali Mehandwas
# Procesando artista 595/824: Prayer of the Dying
# Procesando artista 596/824: Preece
# Procesando artista 597/824: Presence
# Procesando artista 598/824: Psalm One
# Procesando artista 599/824: Pumpkinhead
# Procesando artista 600/824: Putrid Pile
# Procesando artista 601/824: Q'ulle
# Procesando artista 602/824: Quang Linh
# Procesando artista 603/824: R1 La Esencia
# Procesando artista 604/824: RC LORAKL
# Procesando artista 605/824: RSP
# Procesando artista 606/824: Rada Rai
# Procesando artista 607/824: Raising The Veil
# Procesando artista 608/824: Ramsès Damarifa
# Procesando artista 609/824: Rani Chatoorgoon
# Procesando artista 610/824: Rapper Paladino
# Procesando artista 611/824: Raptile
# Procesando artista 612/824: Raykel
# Procesando artista 613/824: Reflection
# Procesando artista 614/824: Rekha Rao
# Procesando artista 615/824: Renato Beltrão
# Procesando artista 616/824: Rev City
# Procesando artista 617/824: Revo-T
# Procesando artista 618/824: Reykon
# Procesando artista 619/824: Rezet
# Procesando artista 620/824: Rezt
# Procesando artista 621/824: Rich
# Procesando artista 622/824: Rich Rocka
# Procesando artista 623/824: Richard Schierer
# Procesando artista 624/824: Rico
# Procesando artista 625/824: Rika Sumalia
# Procesando artista 626/824: Rising Steel
# Procesando artista 627/824: Rita Drangsholt
# Procesando artista 628/824: Ritesh Pandey
# Procesando artista 629/824: Ritual Kannabis
# Procesando artista 630/824: Rocko y Blasty
# Procesando artista 631/824: Rocío Jurado
# Procesando artista 632/824: Rohit Thakor
# Procesando artista 633/824: Rone
# Procesando artista 634/824: Ronnie Biggs
# Procesando artista 635/824: Roolio
# Procesando artista 636/824: Rosita & Club 68
# Procesando artista 637/824: Rudolf Cortés
# Procesando artista 638/824: Ruger 9
# Procesando artista 639/824: Russian Red
# Procesando artista 640/824: Ruth Lorenzo
# Procesando artista 641/824: Ruxe Ruxe
# Procesando artista 642/824: Ryan Anthony
# Procesando artista 643/824: SONDRUM
# Procesando artista 644/824: Sacrament
# Procesando artista 645/824: Salt Ashes
# Procesando artista 646/824: Salvation
# Procesando artista 647/824: San Quinn
# Procesando artista 648/824: Sangdragon
# Procesando artista 649/824: Santi Balmes
# Procesando artista 650/824: Sardar Ali Takkar
# Procesando artista 651/824: Sarita Kharwal
# Procesando artista 652/824: Sashi
# Procesando artista 653/824: Satanic Assault Division
# Procesando artista 654/824: Sauce Twinz
# Procesando artista 655/824: Sauce Walka
# Procesando artista 656/824: Scalpture
# Procesando artista 657/824: Scila
# Procesando artista 658/824: Screaming Condors
# Procesando artista 659/824: Scru Face Jean
# Procesando artista 660/824: Sean Strange
# Procesando artista 661/824: Sekoria
# Procesando artista 662/824: Sekreto
# Procesando artista 663/824: Separation Of Sanity
# Procesando artista 664/824: Sergio Dalma
# Procesando artista 665/824: Serpentor
# Procesando artista 666/824: Servando & Florentino
# Procesando artista 667/824: Seven Stories High
# Procesando artista 668/824: Sgt.Sunshine
# Procesando artista 669/824: Shady Nate
# Procesando artista 670/824: Shahab Ramezan
# Procesando artista 671/824: Shaifer
# Procesando artista 672/824: Shaka Y Dres
# Procesando artista 673/824: Shane Tripp
# Procesando artista 674/824: Shintoma
# Procesando artista 675/824: Show Banga
# Procesando artista 676/824: Shyam Paliwal
# Procesando artista 677/824: Silent Knight
# Procesando artista 678/824: Sin Fang
# Procesando artista 679/824: Sistema Negro
# Procesando artista 680/824: Sixto Rein
# Procesando artista 681/824: Skit Slam
# Procesando artista 682/824: Sky Crypt
# Procesando artista 683/824: Slammin' Thru
# Procesando artista 684/824: Snakedriver
# Procesando artista 685/824: Sniglabandið
# Procesando artista 686/824: Sniper SP
# Procesando artista 687/824: Social Club Misfits
# Procesando artista 688/824: Solacide
# Procesando artista 689/824: Soma Allpass
# Procesando artista 690/824: Sonny & Vaech
# Procesando artista 691/824: Sonny Bo
# Procesando artista 692/824: Sons of Haze
# Procesando artista 693/824: Soraya
# Procesando artista 694/824: Soriano
# Procesando artista 695/824: Sosa Man
# Procesando artista 696/824: Sou El Flotador
# Procesando artista 697/824: Soulhenge
# Procesando artista 698/824: SoundGate
# Procesando artista 699/824: Spectral Darkwave
# Procesando artista 700/824: Speedfreaks
# Procesando artista 701/824: Spyder
# Procesando artista 702/824: Squirrel Cage
# Procesando artista 703/824: Sraw
# Procesando artista 704/824: Stardown
# Procesando artista 705/824: Stauros
# Procesando artista 706/824: Steel God
# Procesando artista 707/824: Stonecutters
# Procesando artista 708/824: Striker
# Procesando artista 709/824: Suffer Remain
# Procesando artista 710/824: Suicide Syndicate
# Procesando artista 711/824: Sun Tzu
# Procesando artista 712/824: Sur Ellz
# Procesando artista 713/824: Suzanne Prentice
# Procesando artista 714/824: Sweens
# Procesando artista 715/824: Swim to Drown
# Procesando artista 716/824: Symptom
# Procesando artista 717/824: Syphilic
# Procesando artista 718/824: Systraskap
# Procesando artista 719/824: São Nunca
# Procesando artista 720/824: T.Y.
# Procesando artista 721/824: TSAR
# Procesando artista 722/824: Taisto Tammi
# Procesando artista 723/824: Tarali Sarma
# Procesando artista 724/824: Tayno
# Procesando artista 725/824: Tejal Thakor
# Procesando artista 726/824: Tempo
# Procesando artista 727/824: TenTwentyEight
# Procesando artista 728/824: Terrier
# Procesando artista 729/824: The Black Monolith
# Procesando artista 730/824: The Butcher's Rodeo
# Procesando artista 731/824: The Canyon Observer
# Procesando artista 732/824: The Ghost
# Procesando artista 733/824: The Heritance
# Procesando artista 734/824: The Machinist
# Procesando artista 735/824: The Noise
# Procesando artista 736/824: The OverAlls
# Procesando artista 737/824: The Prozacs
# Procesando artista 738/824: The Vamps
# Procesando artista 739/824: The White Shadow
# Procesando artista 740/824: The Woman You Saw is the Great City That Rules over the Kings of the Earth
# Procesando artista 741/824: Theo Thomson
# Procesando artista 742/824: Throwed Ese
# Procesando artista 743/824: Thug Trish
# Procesando artista 744/824: Timmie Turnup
# Procesando artista 745/824: Tisu
# Procesando artista 746/824: Tito JV
# Procesando artista 747/824: Torkel T
# Procesando artista 748/824: Toxic Kid
# Procesando artista 749/824: Trankei Republic
# Procesando artista 750/824: Travis Matte and the Kingpins
# Procesando artista 751/824: Trez3
# Procesando artista 752/824: Triaxis
# Procesando artista 753/824: Trille
# Procesando artista 754/824: Trío Martino
# Procesando artista 755/824: Tusama
# Procesando artista 756/824: Tyrant's Kall
# Procesando artista 757/824: Udit Narayan
# Procesando artista 758/824: Ugo Angelito
# Procesando artista 759/824: Utain Prommin
# Procesando artista 760/824: Vaech
# Procesando artista 761/824: Valeriy Syutkin
# Procesando artista 762/824: Vardan
# Procesando artista 763/824: Varry Brava
# Procesando artista 764/824: Vee
# Procesando artista 765/824: Velnias
# Procesando artista 766/824: Vertical
# Procesando artista 767/824: Vice Vukov
# Procesando artista 768/824: Victor Biglione
# Procesando artista 769/824: Vieno Kekkonen
# Procesando artista 770/824: Vince McAley
# Procesando artista 771/824: Vinicio Capossela
# Procesando artista 772/824: Vinod Rathod
# Procesando artista 773/824: Voraz
# Procesando artista 774/824: Vulto.
# Procesando artista 775/824: Vytautas Šiškauskas
# Procesando artista 776/824: W&W
# Procesando artista 777/824: WOLFEN
# Procesando artista 778/824: Waldick Soriano
# Procesando artista 779/824: Walter Losi
# Procesando artista 780/824: Walton
# Procesando artista 781/824: Wambo
# Procesando artista 782/824: Watussi
# Procesando artista 783/824: Whisky
# Procesando artista 784/824: Wild Dogs
# Procesando artista 785/824: Will To Win
# Procesando artista 786/824: Wisin
# Procesando artista 787/824: Witchgrinder
# Procesando artista 788/824: WithoutMind
# Procesando artista 789/824: X-Calio
# Procesando artista 790/824: Y.S
# Procesando artista 791/824: Yansn
# Procesando artista 792/824: Yaves
# Procesando artista 793/824: Yeyow
# Procesando artista 794/824: Yo Gotti
# Procesando artista 795/824: Yofu
# Procesando artista 796/824: Yoherly
# Procesando artista 797/824: Yoi Carrera
# Procesando artista 798/824: Young Chang MC
# Procesando artista 799/824: Young Doe
# Procesando artista 800/824: Yoğun Bakım
# Procesando artista 801/824: Yves V
# Procesando artista 802/824: Z-Ro
# Procesando artista 803/824: Zargof
# Procesando artista 804/824: Zaytoven
# Procesando artista 805/824: Zemlyane
# Procesando artista 806/824: Zepelt
# Procesando artista 807/824: Zion
# Procesando artista 808/824: Zone
# Procesando artista 809/824: Zorimawi
# Procesando artista 810/824: Zubaida Khanum
# Procesando artista 811/824: Zubeen Garg
# Procesando artista 812/824: area3
# Procesando artista 813/824: espiritusanto
# Procesando artista 814/824: filous
# Procesando artista 815/824: fizzytoofab
# Procesando artista 816/824: Галина Журавлёва
# Procesando artista 817/824: Планида
# Procesando artista 818/824: Третий Рим
# Procesando artista 819/824: Шторм
# Procesando artista 820/824: Эскимос Crew
# Procesando artista 821/824: 句潤
# Procesando artista 822/824: 張赫
# Procesando artista 823/824: 朴宰範
# Procesando artista 824/824: 陳良泉
# ✅ Guardado: lastfm_datos.csv (791 artistas)
# ✅ Proceso de Last.fm completado
# 💾 Insertando todos los datos en MySQL...
# 🎤 Insertando artistas en MySQL...
# 🔗 Conectando con MySQL...
# ✅ Conexión establecida: <mysql.connector.connection.MySQLConnection object at 0x0000027E5A20EB90>
# Base de datos activa: ('proyecto_grupal_mod_2',)
# ✅ Artistas insertados en MySQL correctamente
# 🎵 Insertando canciones en MySQL...
# 🔗 Conectando con MySQL...
# ✅ Conexión establecida: <mysql.connector.connection.MySQLConnection object at 0x0000027E59C87E10>
# Base de datos activa: ('proyecto_grupal_mod_2',)
# ✅ Canciones insertadas en MySQL correctamente
# ✅ Todos los datos insertados en MySQL
# ✅ ¡Todo terminado con MySQL!

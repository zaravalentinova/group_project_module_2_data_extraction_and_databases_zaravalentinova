# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import requests
import csv
import re
import mysql.connector 

# Configuración
CLIENT_ID = '9189e74191a848bf82c60efbf06229c6'
CLIENT_SECRET = '36c5b1edfa3744e7ac992361fa2b5b02'
API_KEY_LASTFM = '472626d71b58f9fbdd11821189cb8716'
BASE_URL = "http://ws.audioscrobbler.com/2.0/"

# Configuración MySQL
DB_CONFIG = {
    'user': 'root',
    'password': 'AlumnaAdalab',
    'host': '127.0.0.1',
    'database': 'proyecto_grupal_mod_2'
}

# Función 1: Conectar con Spotify
def conectar_spotify():
    
    sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
        client_id=CLIENT_ID,
        client_secret=CLIENT_SECRET
    ))
    return sp

# Función 2: Buscar canciones de un género y año
def buscar_canciones(sp, genero, ano):
    
    canciones = []
    
    # Buscar en dos páginas (0 y 50)
    for pagina in [0, 50]:
        resultados = sp.search(q=f'genre:"{genero}" year:{ano}', 
                              type='track', 
                              limit=50, 
                              offset=pagina)
        
        for cancion in resultados['tracks']['items']:
            # Obtener nombres de artistas
            artistas = []
            for artista in cancion['artists']:
                artistas.append(artista['name'])
            
            # Crear diccionario con datos de la canción
            datos_cancion = {
                'artistas': ', '.join(artistas),
                'colaboracion': len(artistas) > 1,
                'genero_musical': genero,
                'nombre': cancion['name'],
                'ano_lanzamiento': cancion['album']['release_date'][:4],
                'id': cancion['id']
            }
            canciones.append(datos_cancion)
    
    return canciones

# Función 3: Obtener todas las canciones
def obtener_todas_canciones():
    
    # Conectar con Spotify
    sp = conectar_spotify()
    
    # Listas de géneros y años
    generos = ['pop', 'metal', 'reggaeton', 'rap']
    años = [2015, 2016]
    
    # Lista para guardar todas las canciones
    todas_canciones = []
    
    # Buscar canciones para cada género y año
    for genero in generos:
        print(f"Buscando canciones de {genero}...")
        for ano in años:
            print(f"  Año {ano}...")
            canciones = buscar_canciones(sp, genero, ano)
            todas_canciones.extend(canciones)
    
    return todas_canciones

# Función 4: Guardar canciones en CSV
def guardar_canciones_csv(canciones):
    
    with open('spotify_datos.csv', 'w', newline='', encoding='utf-8') as archivo:
        campos = ['artistas', 'colaboracion', 'genero_musical', 'nombre', 'ano_lanzamiento', 'id']
        escritor = csv.DictWriter(archivo, fieldnames=campos)
        escritor.writeheader()
        escritor.writerows(canciones)
    
    print(f"✅ Guardado: spotify_datos.csv ({len(canciones)} canciones)")

# Función 5: Leer artistas del CSV
def leer_artistas_csv():
    
    df = pd.read_csv('spotify_datos.csv')
    
    # Lista para todos los artistas
    todos_artistas = []
    
    # Procesar cada fila
    for fila in df['artistas']:
        # Separar artistas por comas
        lista_artistas = fila.split(',')
        for artista in lista_artistas:
            artista_limpio = artista.strip()  # Quitar espacios
            if artista_limpio:  # Si no está vacío
                todos_artistas.append(artista_limpio)
    
    # Quitar duplicados y ordenar
    artistas_unicos = list(set(todos_artistas))
    artistas_unicos.sort()
    
    print(f"Artistas únicos encontrados: {len(artistas_unicos)}")
    return artistas_unicos

# Función 6: Quitar etiquetas HTML
def quitar_html(texto):
    
    if texto:
        texto_limpio = re.sub('<[^<]+?>', '', texto)
        return texto_limpio.strip()
    return ''

# Función 7: Buscar información de un artista en Last.fm
def buscar_artista_lastfm(nombre_artista):
    
    # Parámetros para la API
    parametros = {
        "method": "artist.getInfo",
        "artist": nombre_artista,
        "api_key": API_KEY_LASTFM,
        "format": "json",
        "lang": "es"
    }
    
    # Hacer petición a la API
    respuesta = requests.get(BASE_URL, params=parametros)
    datos = respuesta.json()
    
    # Verificar si encontró el artista
    if "artist" in datos:
        artista_info = datos['artist']
        
        # Obtener biografía
        biografia = ''
        if 'bio' in artista_info and 'content' in artista_info['bio']:
            biografia = quitar_html(artista_info['bio']['content'])
        
        # Obtener estadísticas
        playcount = 0
        oyentes = 0
        if 'stats' in artista_info:
            playcount = artista_info['stats'].get('playcount', 0)
            oyentes = artista_info['stats'].get('listeners', 0)
        
        # Obtener artistas similares
        similares = []
        if 'similar' in artista_info and 'artist' in artista_info['similar']:
            for similar in artista_info['similar']['artist']:
                similares.append(similar.get('name', ''))
        
        # Crear diccionario con la información
        info_artista = {
            'artist': nombre_artista,
            'biografia': biografia,
            'playcount': playcount,
            'oyentes': oyentes,
            'similares': ', '.join(similares)
        }
        
        return info_artista
    
    return None

# Función 8: Obtener información de todos los artistas
def obtener_info_artistas():
    
    # Leer artistas del CSV
    artistas = leer_artistas_csv()
    
    # Lista para guardar información de artistas
    info_artistas = []
    
    # Buscar información de cada artista
    contador = 0
    for artista in artistas:
        contador += 1
        print(f"Procesando artista {contador}/{len(artistas)}: {artista}")
        
        info = buscar_artista_lastfm(artista)
        if info:
            info_artistas.append(info)
    
    return info_artistas

# Función 9: Guardar información de artistas en CSV
def guardar_artistas_csv(info_artistas):
    
    with open('lastfm_datos.csv', 'w', newline='', encoding='utf-8') as archivo:
        campos = ['artist', 'biografia', 'playcount', 'oyentes', 'similares']
        escritor = csv.DictWriter(archivo, fieldnames=campos)
        escritor.writeheader()
        escritor.writerows(info_artistas)
    
    print(f"✅ Guardado: lastfm_datos.csv ({len(info_artistas)} artistas)")

# Función 10: Proceso completo de Spotify
def proceso_spotify():
    
    print("🎵 Iniciando proceso de Spotify...")
    
    # Obtener canciones
    canciones = obtener_todas_canciones()
    
    # Guardar en CSV
    guardar_canciones_csv(canciones)
    
    print("✅ Proceso de Spotify completado")

# Función 11: Proceso completo de Last.fm
def proceso_lastfm():
    
    print("🎤 Iniciando proceso de Last.fm...")
    
    # Obtener información de artistas
    info_artistas = obtener_info_artistas()
    
    # Guardar en CSV
    guardar_artistas_csv(info_artistas)
    
    print("✅ Proceso de Last.fm completado")

# Función 12: Proceso completo
def proceso_completo():
    
    print("🚀 Iniciando proceso completo...")
    
    # Primero Spotify
    proceso_spotify()
    
    # Luego Last.fm
    proceso_lastfm()
    
    print("✅ ¡Todo terminado!")

# Función 13: Conectar con MySQL
def conectar_mysql():
    
    print("🔗 Conectando con MySQL...")
    
    cnx = mysql.connector.connect(**DB_CONFIG)
    print("✅ Conexión establecida:", cnx)
    
    # Verificar base de datos activa
    mycursor = cnx.cursor()
    mycursor.execute("SELECT DATABASE();")
    db_actual = mycursor.fetchone()
    print("Base de datos activa:", db_actual)
    mycursor.close()
    
    return cnx

# Función 14: Insertar artistas en MySQL
def insertar_artistas_mysql():
    
    print("🎤 Insertando artistas en MySQL...")
    
    # Conectar con MySQL
    cnx = conectar_mysql()
    mycursor = cnx.cursor()
    
    # Leer archivo CSV
    with open('lastfm_datos.csv', 'r', encoding='utf-8') as archivo_csv:
        reader = csv.DictReader(archivo_csv)
        
        for fila in reader:
            sql = """
                INSERT INTO artistas (nombre, biografia, playcount, oyentes, similares)
                VALUES (%s, %s, %s, %s, %s)
                ON DUPLICATE KEY UPDATE 
                    biografia = VALUES(biografia),
                    playcount = VALUES(playcount),
                    oyentes = VALUES(oyentes),
                    similares = VALUES(similares)
            """
            
            valores = (
                fila['artist'],
                fila['biografia'],
                int(fila['playcount']),
                int(fila['oyentes']),
                fila.get('similares', '')
            )
            
            mycursor.execute(sql, valores)
    
    # Guardar cambios
    cnx.commit()
    mycursor.close()
    cnx.close()
    
    print("✅ Artistas insertados en MySQL correctamente")

# Función 15: Insertar canciones en MySQL
def insertar_canciones_mysql():
    
    print("🎵 Insertando canciones en MySQL...")
    
    # Conectar con MySQL
    cnx = conectar_mysql()
    mycursor = cnx.cursor()
    mycursor_bucle = cnx.cursor()
    
    # Leer archivo CSV
    with open('spotify_datos.csv', 'r', encoding='utf-8') as archivo_csv:
        reader = csv.DictReader(archivo_csv)
        
        for fila in reader:
            # 1. Insertar canción
            sql_cancion = """
                INSERT INTO canciones (nombre, genero_musical, tipo, año_lanzamiento, id_spotify)
                VALUES (%s, %s, %s, %s, %s)
                ON DUPLICATE KEY UPDATE nombre = VALUES(nombre)
            """
            
            valores_cancion = (
                fila['nombre'],
                fila['genero_musical'],
                fila['genero_musical'],
                int(fila['ano_lanzamiento']),
                fila['id']
            )
            
            mycursor.execute(sql_cancion, valores_cancion)
            
            # 2. Obtener ID de la canción
            mycursor_bucle.execute("SELECT id_cancion FROM canciones WHERE id_spotify = %s", (fila['id'],))
            id_cancion = mycursor_bucle.fetchone()[0]
            
            # 3. Insertar relación canción-artista
            artistas = [art.strip() for art in fila['artistas'].split(',')]
            for artista in artistas:
                # Buscar ID del artista
                mycursor_bucle.execute("SELECT id_artista FROM artistas WHERE nombre = %s", (artista,))
                res = mycursor_bucle.fetchone()
                
                if res:
                    id_artista = res[0]
                    sql_relacion = """
                        INSERT INTO canciones_artistas (id_cancion, id_artista)
                        VALUES (%s, %s)
                        ON DUPLICATE KEY UPDATE id_cancion = id_cancion
                    """
                    mycursor_bucle.execute(sql_relacion, (id_cancion, id_artista))
    
    # Guardar cambios
    cnx.commit()
    mycursor.close()
    mycursor_bucle.close()
    cnx.close()
    
    print("✅ Canciones insertadas en MySQL correctamente")

# Función 16: Insertar todos los datos en MySQL
def insertar_datos_mysql():
    
    print("💾 Insertando todos los datos en MySQL...")
    
    # Primero insertar artistas
    insertar_artistas_mysql()
    
    # Luego insertar canciones
    insertar_canciones_mysql()
    
    print("✅ Todos los datos insertados en MySQL")

# Función 17: Proceso completo con MySQL
def proceso_completo_mysql():
    
    print("🚀 Iniciando proceso completo con MySQL...")
    
    # 1. Proceso de Spotify
    proceso_spotify()
    
    # 2. Proceso de Last.fm
    proceso_lastfm()
    
    # 3. Insertar en MySQL
    insertar_datos_mysql()
    
    print("✅ ¡Todo terminado con MySQL!")

# Función 18: Solo MySQL (solo inserta los datos si ya tienes los CSV)
def solo_mysql():
    
    print("💾 Insertando datos existentes en MySQL...")
    insertar_datos_mysql()

# Ejecutar el programa
if __name__ == "__main__":
    # Opción 1: Proceso completo con MySQL
    proceso_completo_mysql()
    
    # Opción 2: Solo MySQL (descomenta la línea siguiente)
# Out:
# 🚀 Iniciando proceso completo con MySQL...
# 🎵 Iniciando proceso de Spotify...
# Buscando canciones de pop...
#   Año 2015...
#   Año 2016...
# Buscando canciones de metal...
#   Año 2015...
#   Año 2016...
# Buscando canciones de reggaeton...
#   Año 2015...
#   Año 2016...
# Buscando canciones de rap...
#   Año 2015...
#   Año 2016...
# ✅ Guardado: spotify_datos.csv (800 canciones)
# ✅ Proceso de Spotify completado
# 🎤 Iniciando proceso de Last.fm...
# Artistas únicos encontrados: 833
# Procesando artista 1/833: 13 Steps
# Procesando artista 2/833: 38 Spesh
# Procesando artista 3/833: 46Simmy
# Procesando artista 4/833: 679
# Procesando artista 5/833: 8Ball & MJG
# Procesando artista 6/833: 995
# Procesando artista 7/833: A Constant Storm
# Procesando artista 8/833: A$AP ANT
# Procesando artista 9/833: AFROJACK
# Procesando artista 10/833: ARY
# Procesando artista 11/833: Abandoned Elysium
# Procesando artista 12/833: Abida Parveen
# Procesando artista 13/833: Abigorum
# Procesando artista 14/833: Absent Minded
# Procesando artista 15/833: Aeternus Prophet
# Procesando artista 16/833: Afrigo Band
# Procesando artista 17/833: After Apocalypse
# Procesando artista 18/833: Agnaldo Timoteo
# Procesando artista 19/833: Ajmal Waseem
# Procesando artista 20/833: Akem Manah
# Procesando artista 21/833: Alaza
# Procesando artista 22/833: Alex Jordahl
# Procesando artista 23/833: Alex Orellana
# Procesando artista 24/833: Alexander DJ
# Procesando artista 25/833: Alienadept
# Procesando artista 26/833: Alkawi
# Procesando artista 27/833: Alla Pugacheva
# Procesando artista 28/833: Amado Tovar
# Procesando artista 29/833: Amaro
# Procesando artista 30/833: Amaro.
# Procesando artista 31/833: Amongster
# Procesando artista 32/833: Andy Boy
# Procesando artista 33/833: Andy G
# Procesando artista 34/833: Angel & Ranking
# Procesando artista 35/833: Angel 7
# Procesando artista 36/833: Angel Doze
# Procesando artista 37/833: Anmol Sayal
# Procesando artista 38/833: Antonello Giliberto
# Procesando artista 39/833: Aornos
# Procesando artista 40/833: April in Flames
# Procesando artista 41/833: Aran One
# Procesando artista 42/833: Arbach
# Procesando artista 43/833: Are el Real
# Procesando artista 44/833: Arianna Puello
# Procesando artista 45/833: Arjan Korkaj
# Procesando artista 46/833: Arjay
# Procesando artista 47/833: Arkham Witch
# Procesando artista 48/833: Artista Rosario
# Procesando artista 49/833: Aryon
# Procesando artista 50/833: Asco100k
# Procesando artista 51/833: Asees Kaur
# Procesando artista 52/833: Asgrauw
# Procesando artista 53/833: Asha Vaishnav
# Procesando artista 54/833: Astral Experience
# Procesando artista 55/833: Atlas
# Procesando artista 56/833: Atlántico Negro
# Procesando artista 57/833: Atta Ullah Khan Esakhelvi
# Procesando artista 58/833: Avitas
# Procesando artista 59/833: Awaiting Ezkaton
# Procesando artista 60/833: Awake Again
# Procesando artista 61/833: Awake In A Dream
# Procesando artista 62/833: Awakened Inferno
# Procesando artista 63/833: Aye Mammoth
# Procesando artista 64/833: Aylu
# Procesando artista 65/833: Azorap
# Procesando artista 66/833: B. Magic
# Procesando artista 67/833: BADSISTA
# Procesando artista 68/833: BIGBABYGUCCI
# Procesando artista 69/833: BLINDMAN
# Procesando artista 70/833: BTR
# Procesando artista 71/833: Ba-Kha
# Procesando artista 72/833: Baby Joe
# Procesando artista 73/833: Baby Noel
# Procesando artista 74/833: Bako
# Procesando artista 75/833: Baltik Beatz
# Procesando artista 76/833: Be the Part
# Procesando artista 77/833: Beat Punches
# Procesando artista 78/833: BeatBoy
# Procesando artista 79/833: Bello Spark
# Procesando artista 80/833: Beltito "Esta En El Beat"
# Procesando artista 81/833: Benjunior
# Procesando artista 82/833: Benny Benni
# Procesando artista 83/833: Benthik Zone
# Procesando artista 84/833: Bernardo Vazquez
# Procesando artista 85/833: Big Boy
# Procesando artista 86/833: Billy Hoyle
# Procesando artista 87/833: Bing
# Procesando artista 88/833: Bird El Macriado
# Procesando artista 89/833: Biznaga
# Procesando artista 90/833: Bizzy Bone
# Procesando artista 91/833: Black Medicine
# Procesando artista 92/833: BlackBelt Poemz
# Procesando artista 93/833: Blacksoul Seraphim
# Procesando artista 94/833: Bleating Apocalypse
# Procesando artista 95/833: Blebla
# Procesando artista 96/833: Blessed Sinner
# Procesando artista 97/833: Bloodphemy
# Procesando artista 98/833: Bloody Hell
# Procesando artista 99/833: Bloody Morgue
# Procesando artista 100/833: Bo Deal
# Procesando artista 101/833: Bom Bahadur Karki
# Procesando artista 102/833: Bosski
# Procesando artista 103/833: Box
# Procesando artista 104/833: Boy Big
# Procesando artista 105/833: Brabo Gator
# Procesando artista 106/833: Breno Ruiz
# Procesando artista 107/833: BrianWith2Eyes
# Procesando artista 108/833: Brudywr
# Procesando artista 109/833: Brytiago
# Procesando artista 110/833: Buhay Cali
# Procesando artista 111/833: Bullet Course
# Procesando artista 112/833: Bulu Mukarung
# Procesando artista 113/833: Bunbury
# Procesando artista 114/833: Burger Weekends
# Procesando artista 115/833: Butchery
# Procesando artista 116/833: Buxxi
# Procesando artista 117/833: By Will Alone
# Procesando artista 118/833: C Fat
# Procesando artista 119/833: C-Bo
# Procesando artista 120/833: C-Sharp
# Procesando artista 121/833: C.M.L.
# Procesando artista 122/833: CD9
# Procesando artista 123/833: CVPELLV
# Procesando artista 124/833: Cadaverous Incarnate
# Procesando artista 125/833: Cal Smith
# Procesando artista 126/833: Calamity
# Procesando artista 127/833: Cameron Blake
# Procesando artista 128/833: Camila Campos
# Procesando artista 129/833: Camileazy
# Procesando artista 130/833: Carlito
# Procesando artista 131/833: Carnal Blasphemy
# Procesando artista 132/833: Carola
# Procesando artista 133/833: Carolyn Rodriguez
# Procesando artista 134/833: Carved
# Procesando artista 135/833: Casti
# Procesando artista 136/833: Ceachepe
# Procesando artista 137/833: Cebrock A.K.A el Capitan Del Bar
# Procesando artista 138/833: Cell 9
# Procesando artista 139/833: ChaMane
# Procesando artista 140/833: Chacal Men
# Procesando artista 141/833: Chantelle
# Procesando artista 142/833: Charly Humos
# Procesando artista 143/833: Charry Slow
# Procesando artista 144/833: Cheka
# Procesando artista 145/833: Cherezade
# Procesando artista 146/833: Cherie Hughes
# Procesando artista 147/833: Chillin
# Procesando artista 148/833: Chino & Nacho
# Procesando artista 149/833: Chostin
# Procesando artista 150/833: Chris Ward
# Procesando artista 151/833: Christian Cat
# Procesando artista 152/833: Christian Liebeskind
# Procesando artista 153/833: Chunk
# Procesando artista 154/833: Cira
# Procesando artista 155/833: Circle Spectre Haunting
# Procesando artista 156/833: Classic Noise
# Procesando artista 157/833: Cleiton Rossi
# Procesando artista 158/833: Concatenation
# Procesando artista 159/833: Condescension
# Procesando artista 160/833: Condition Red
# Procesando artista 161/833: Controlversos
# Procesando artista 162/833: Cosmivore
# Procesando artista 163/833: Cricet
# Procesando artista 164/833: Cristóbal Jiménez
# Procesando artista 165/833: Crossing Death
# Procesando artista 166/833: Cruch Calhoun
# Procesando artista 167/833: Cryostasium
# Procesando artista 168/833: Crystal Pyramid
# Procesando artista 169/833: Cupid's Carnival
# Procesando artista 170/833: Curtis Mayz
# Procesando artista 171/833: Cyborg AOS
# Procesando artista 172/833: Cyco City
# Procesando artista 173/833: Cymarshall Law
# Procesando artista 174/833: Cypress Spring
# Procesando artista 175/833: Cómodo
# Procesando artista 176/833: D-Aye
# Procesando artista 177/833: D-Baby
# Procesando artista 178/833: D.O.N.S.
# Procesando artista 179/833: DB Tha General
# Procesando artista 180/833: DJ Elder
# Procesando artista 181/833: DJ Kadel
# Procesando artista 182/833: DJ Memo
# Procesando artista 183/833: DJ Nelson
# Procesando artista 184/833: DJ X.O.
# Procesando artista 185/833: DMEI
# Procesando artista 186/833: DTM
# Procesando artista 187/833: Daddy Yankee
# Procesando artista 188/833: Dae Dae Mob
# Procesando artista 189/833: Damien Jurado
# Procesando artista 190/833: Daniel Huen
# Procesando artista 191/833: Danny Boone
# Procesando artista 192/833: Darell
# Procesando artista 193/833: Darom Dabro
# Procesando artista 194/833: Das Ding ausm Sumpf
# Procesando artista 195/833: Dasoul
# Procesando artista 196/833: Datcha Dollar'z
# Procesando artista 197/833: Dave Pell
# Procesando artista 198/833: David Barrull
# Procesando artista 199/833: David Ramirez
# Procesando artista 200/833: David Versailles
# Procesando artista 201/833: Dead Rites
# Procesando artista 202/833: Deadly
# Procesando artista 203/833: Death Blossoms
# Procesando artista 204/833: Deathtune
# Procesando artista 205/833: Decayed
# Procesando artista 206/833: Defect Designer
# Procesando artista 207/833: Demo
# Procesando artista 208/833: Den Andre Lys
# Procesando artista 209/833: Desmond Jones
# Procesando artista 210/833: Dexys Midnight Runners
# Procesando artista 211/833: Diana
# Procesando artista 212/833: Diana Navarro
# Procesando artista 213/833: Dinesh Mali
# Procesando artista 214/833: DiseNgaged
# Procesando artista 215/833: Disillusion Effect
# Procesando artista 216/833: Diskopantera
# Procesando artista 217/833: Dissecdead
# Procesando artista 218/833: Distant Past
# Procesando artista 219/833: Dixzon
# Procesando artista 220/833: Dj Osir
# Procesando artista 221/833: Dj Pache
# Procesando artista 222/833: Dj Sir Cyber
# Procesando artista 223/833: Dj Suddenbeatz
# Procesando artista 224/833: Dj Taktel
# Procesando artista 225/833: Dji Tafinha
# Procesando artista 226/833: Dominance
# Procesando artista 227/833: Dominique A
# Procesando artista 228/833: Domy
# Procesando artista 229/833: Don Chezina
# Procesando artista 230/833: Dorian Keller
# Procesando artista 231/833: Dryca Ryzzo
# Procesando artista 232/833: Dulce Maria
# Procesando artista 233/833: Durga Jasraj
# Procesando artista 234/833: Dvice
# Procesando artista 235/833: Dzö-nga
# Procesando artista 236/833: EF
# Procesando artista 237/833: Ecos del Rocío
# Procesando artista 238/833: Eddie MMack
# Procesando artista 239/833: Eddy XP
# Procesando artista 240/833: Eigentijdse Jeugd
# Procesando artista 241/833: Einar & Einar
# Procesando artista 242/833: Einstein NRC
# Procesando artista 243/833: El Barbero
# Procesando artista 244/833: El Calle Latina
# Procesando artista 245/833: El Hombre Viento
# Procesando artista 246/833: El Mayor Clasico
# Procesando artista 247/833: El Núm3ro
# Procesando artista 248/833: Eladio y Los Seres Queridos
# Procesando artista 249/833: Elarcos
# Procesando artista 250/833: Electroqute
# Procesando artista 251/833: Elegiac
# Procesando artista 252/833: Elias Diaz
# Procesando artista 253/833: Elio Mafiaboy
# Procesando artista 254/833: Embalming Theatre
# Procesando artista 255/833: Emergency Broadcast
# Procesando artista 256/833: End-Time Illusion
# Procesando artista 257/833: Endless Reign
# Procesando artista 258/833: Envinya
# Procesando artista 259/833: Equidad Catacraneo
# Procesando artista 260/833: Ervin River
# Procesando artista 261/833: Eryn Turner
# Procesando artista 262/833: Eternal Sorrow
# Procesando artista 263/833: Evan
# Procesando artista 264/833: Evil Conspiracy
# Procesando artista 265/833: F2 La Liga Latina
# Procesando artista 266/833: FVBIIAN
# Procesando artista 267/833: Fable
# Procesando artista 268/833: Fable The Poet
# Procesando artista 269/833: Famous Addonis
# Procesando artista 270/833: Família 33
# Procesando artista 271/833: Farasu
# Procesando artista 272/833: Farruko
# Procesando artista 273/833: Fatal Destiny
# Procesando artista 274/833: Feanor Omega
# Procesando artista 275/833: Fhat.R
# Procesando artista 276/833: Fingazz
# Procesando artista 277/833: Finlanders
# Procesando artista 278/833: Fisko23
# Procesando artista 279/833: FlockaTrent
# Procesando artista 280/833: Forever
# Procesando artista 281/833: Formally Lethargic
# Procesando artista 282/833: Fortíð
# Procesando artista 283/833: Fran Ocaña
# Procesando artista 284/833: Franco The Kaizer
# Procesando artista 285/833: Fredric
# Procesando artista 286/833: Frida Andersson
# Procesando artista 287/833: Frontload
# Procesando artista 288/833: Fuckaine
# Procesando artista 289/833: Funnyboy
# Procesando artista 290/833: Furiah
# Procesando artista 291/833: G-Val
# Procesando artista 292/833: G. Goss
# Procesando artista 293/833: GHOLD
# Procesando artista 294/833: Gabby Annalyse
# Procesando artista 295/833: Gabo El De La Comision
# Procesando artista 296/833: Gajendra Ajmera
# Procesando artista 297/833: Galante "El Emperador"
# Procesando artista 298/833: Galavant
# Procesando artista 299/833: Galindo Again
# Procesando artista 300/833: Geenkon
# Procesando artista 301/833: Ghazala Javed
# Procesando artista 302/833: Ghost of Mary
# Procesando artista 303/833: Gigolo
# Procesando artista 304/833: Gizeh
# Procesando artista 305/833: Glamrock Brothers
# Procesando artista 306/833: Global Deejays
# Procesando artista 307/833: Goatblood
# Procesando artista 308/833: Golden Gun
# Procesando artista 309/833: Goldie Lookin Chain
# Procesando artista 310/833: Goldini Bagwell
# Procesando artista 311/833: Graça Music
# Procesando artista 312/833: Grilocks
# Procesando artista 313/833: Grises
# Procesando artista 314/833: Grämsn
# Procesando artista 315/833: Grÿmt
# Procesando artista 316/833: Guelo Star
# Procesando artista 317/833: Guerrilleroz
# Procesando artista 318/833: Guillamino
# Procesando artista 319/833: Gustavo Elis
# Procesando artista 320/833: H.T. Hayko
# Procesando artista 321/833: Halve Neuro
# Procesando artista 322/833: Hansa
# Procesando artista 323/833: Harrow
# Procesando artista 324/833: Harsh Mali
# Procesando artista 325/833: Hate in Flesh
# Procesando artista 326/833: Hazell Dean
# Procesando artista 327/833: Hazte lapón
# Procesando artista 328/833: Heemi
# Procesando artista 329/833: Henry Mendez
# Procesando artista 330/833: Hercunia
# Procesando artista 331/833: Hereza
# Procesando artista 332/833: Hira
# Procesando artista 333/833: Hot Boy Turk
# Procesando artista 334/833: Hugo Liscano
# Procesando artista 335/833: Human Waste
# Procesando artista 336/833: Humungus
# Procesando artista 337/833: Hung On Horns
# Procesando artista 338/833: Hungry Wölf
# Procesando artista 339/833: Hyonblud
# Procesando artista 340/833: Hæresiarchs Of Dis
# Procesando artista 341/833: Ian the Young Rich Boy
# Procesando artista 342/833: Immemoreal
# Procesando artista 343/833: Inbreeding Sick
# Procesando artista 344/833: Incinerating Prophecies
# Procesando artista 345/833: Inferno
# Procesando artista 346/833: Innerstate Ike
# Procesando artista 347/833: Insaniam
# Procesando artista 348/833: Ira!
# Procesando artista 349/833: Iran Costa
# Procesando artista 350/833: Isengrim
# Procesando artista 351/833: Isolated Antagonist
# Procesando artista 352/833: Ivan Ferreiro
# Procesando artista 353/833: Ivy Queen
# Procesando artista 354/833: J Alvarez
# Procesando artista 355/833: J RIVERS
# Procesando artista 356/833: J.A.Z. (Justified And Zealous)
# Procesando artista 357/833: JC Parkell Brown
# Procesando artista 358/833: JFT
# Procesando artista 359/833: Jacques Houdek
# Procesando artista 360/833: Jae Millz
# Procesando artista 361/833: Jalpa Dave
# Procesando artista 362/833: Javed Ali
# Procesando artista 363/833: Javier Galué
# Procesando artista 364/833: Jawcen
# Procesando artista 365/833: Jay Ef
# Procesando artista 366/833: Jay y el Punto
# Procesando artista 367/833: Jaydan
# Procesando artista 368/833: Jayder
# Procesando artista 369/833: Jeepz
# Procesando artista 370/833: Jengloth
# Procesando artista 371/833: Jens Book-Jenssen
# Procesando artista 372/833: Jes Latino
# Procesando artista 373/833: Jhakal
# Procesando artista 374/833: Jib Artisan
# Procesando artista 375/833: Jiggy Drama
# Procesando artista 376/833: Jignesh Barot
# Procesando artista 377/833: Jignesh Kaviraj
# Procesando artista 378/833: Joddski
# Procesando artista 379/833: Joe Blow
# Procesando artista 380/833: Joe Frawley
# Procesando artista 381/833: Joel
# Procesando artista 382/833: Johan Kim
# Procesando artista 383/833: John Hidalgo
# Procesando artista 384/833: Joseph A. Peragine
# Procesando artista 385/833: José Ricardo Williams
# Procesando artista 386/833: João Gustavo e Murilo
# Procesando artista 387/833: Juan Gambino
# Procesando artista 388/833: Juan Perro
# Procesando artista 389/833: Juanchu
# Procesando artista 390/833: Juanka
# Procesando artista 391/833: Julillo
# Procesando artista 392/833: Junebug Slim
# Procesando artista 393/833: Juno "The Hitmaker"
# Procesando artista 394/833: Jutha & Small
# Procesando artista 395/833: Juventud Juché
# Procesando artista 396/833: KARWAN XABATI
# Procesando artista 397/833: KSHMR
# Procesando artista 398/833: Kaines
# Procesando artista 399/833: Kamya
# Procesando artista 400/833: Kangal
# Procesando artista 401/833: Kanu Patel
# Procesando artista 402/833: Karel Vlach se svým orchestrem
# Procesando artista 403/833: Karnak Seti
# Procesando artista 404/833: Kartier
# Procesando artista 405/833: Kashflowtoofab
# Procesando artista 406/833: Kate Ryan
# Procesando artista 407/833: Kavelo Y No Drama
# Procesando artista 408/833: Keishal
# Procesando artista 409/833: Ketzer
# Procesando artista 410/833: Kevin Rowland
# Procesando artista 411/833: Khepri
# Procesando artista 412/833: Kholebeatz
# Procesando artista 413/833: Khushboo Jain
# Procesando artista 414/833: Kiko y Shara
# Procesando artista 415/833: King
# Procesando artista 416/833: King K.O
# Procesando artista 417/833: King Kuma
# Procesando artista 418/833: King Tc
# Procesando artista 419/833: Kinjal Dave
# Procesando artista 420/833: Kirtidan Gadhvi
# Procesando artista 421/833: Klapa Sveti Juraj HRM
# Procesando artista 422/833: Kronos Resistor
# Procesando artista 423/833: Kurt Foss
# Procesando artista 424/833: Kyle Rapps
# Procesando artista 425/833: Kôba
# Procesando artista 426/833: L'Officina Della Camomilla
# Procesando artista 427/833: L-ALI
# Procesando artista 428/833: LAKSHMI
# Procesando artista 429/833: La Barbería Del Sur
# Procesando artista 430/833: La Bohème
# Procesando artista 431/833: La Pols i l'Era
# Procesando artista 432/833: La Unión
# Procesando artista 433/833: Lalitya Munshaw
# Procesando artista 434/833: Lapsus Dei
# Procesando artista 435/833: Larva
# Procesando artista 436/833: Las Aves Cantoras
# Procesando artista 437/833: Lasai
# Procesando artista 438/833: Latina Sativa
# Procesando artista 439/833: Lawrence P Dsouza
# Procesando artista 440/833: Leafter
# Procesando artista 441/833: Leandro Marques
# Procesando artista 442/833: Leandro Solano
# Procesando artista 443/833: Lellurano
# Procesando artista 444/833: Lennox
# Procesando artista 445/833: Lenny Tavárez
# Procesando artista 446/833: Lick-G
# Procesando artista 447/833: Lifted Deezie
# Procesando artista 448/833: Lightshow
# Procesando artista 449/833: Liis Lemsalu
# Procesando artista 450/833: Lil 8
# Procesando artista 451/833: Lil Cuete
# Procesando artista 452/833: Lil Scrappy
# Procesando artista 453/833: Lil Sick
# Procesando artista 454/833: Lil Wyte
# Procesando artista 455/833: Lil Yase
# Procesando artista 456/833: Lil' Flip
# Procesando artista 457/833: Liliu
# Procesando artista 458/833: Linco
# Procesando artista 459/833: Lipless
# Procesando artista 460/833: Look the Part
# Procesando artista 461/833: Lord Almighty
# Procesando artista 462/833: Los Corraleros De Majagual
# Procesando artista 463/833: Los Secretos
# Procesando artista 464/833: Lucho Argain
# Procesando artista 465/833: Lucifer's Legion
# Procesando artista 466/833: Lucky Luciano
# Procesando artista 467/833: Lucy
# Procesando artista 468/833: Lynn Anderson
# Procesando artista 469/833: MC Eiht
# Procesando artista 470/833: MC haNsAi
# Procesando artista 471/833: MJG
# Procesando artista 472/833: MN MC
# Procesando artista 473/833: MV Bill
# Procesando artista 474/833: Mackie
# Procesando artista 475/833: Madd Illz
# Procesando artista 476/833: Magic Juan
# Procesando artista 477/833: Makziel
# Procesando artista 478/833: Manuel J. Bernal
# Procesando artista 479/833: Marey
# Procesando artista 480/833: Maria Butaciu
# Procesando artista 481/833: Maria Cecília & Rodolfo
# Procesando artista 482/833: Marii
# Procesando artista 483/833: Mario Castelnuovo
# Procesando artista 484/833: Marisol
# Procesando artista 485/833: Mariwan Sarawy
# Procesando artista 486/833: Mariza
# Procesando artista 487/833: Markku Suominen
# Procesando artista 488/833: Marnik
# Procesando artista 489/833: Martillo Austral
# Procesando artista 490/833: Martina Stoessel
# Procesando artista 491/833: Marvin Satiro
# Procesando artista 492/833: Marxx
# Procesando artista 493/833: Math and Physics Club
# Procesando artista 494/833: Mauros Amnos
# Procesando artista 495/833: Mausoleum Gate
# Procesando artista 496/833: Maxposs
# Procesando artista 497/833: Mc Brahma
# Procesando artista 498/833: Mehdi Hassan
# Procesando artista 499/833: Mehrab
# Procesando artista 500/833: Mel
# Procesando artista 501/833: Meliah Rage
# Procesando artista 502/833: Mi Capitán
# Procesando artista 503/833: Michael Sullivan
# Procesando artista 504/833: Midaircondo
# Procesando artista 505/833: Midnight Peacocks
# Procesando artista 506/833: Miguel B.
# Procesando artista 507/833: Mike Lucazz
# Procesando artista 508/833: Miky Woodz
# Procesando artista 509/833: Mill3r
# Procesando artista 510/833: Misié Sadik
# Procesando artista 511/833: Mobi Dixon
# Procesando artista 512/833: Moemaw Naedon
# Procesando artista 513/833: Mohrez
# Procesando artista 514/833: Mojinos Escozios
# Procesando artista 515/833: Molotow Brass Orkestar
# Procesando artista 516/833: Momtaz
# Procesando artista 517/833: Monoulious DOP
# Procesando artista 518/833: Monsta
# Procesando artista 519/833: Mortal Torment
# Procesando artista 520/833: Motherfucker
# Procesando artista 521/833: Motörhead
# Procesando artista 522/833: Mozzy
# Procesando artista 523/833: Mr. Joeker
# Procesando artista 524/833: Mr. P.J.
# Procesando artista 525/833: Mr. Piif
# Procesando artista 526/833: Murciano Total
# Procesando artista 527/833: Musarrat Nazir
# Procesando artista 528/833: Mym
# Procesando artista 529/833: Márcia Bonfim
# Procesando artista 530/833: Mägo de Oz
# Procesando artista 531/833: NA emcee
# Procesando artista 532/833: NT
# Procesando artista 533/833: Nadhira
# Procesando artista 534/833: Naseebo Lal
# Procesando artista 535/833: Natali Nascimento
# Procesando artista 536/833: Nauí
# Procesando artista 537/833: Ndee Naldinho
# Procesando artista 538/833: Neel Akash
# Procesando artista 539/833: Neelkamal Singh
# Procesando artista 540/833: Neetu Singh
# Procesando artista 541/833: Negative Thought Process
# Procesando artista 542/833: Nekro Drunkz
# Procesando artista 543/833: Neleonard
# Procesando artista 544/833: Nelson Freitas
# Procesando artista 545/833: Nene Marti
# Procesando artista 546/833: Neno Calvin
# Procesando artista 547/833: Nephilim
# Procesando artista 548/833: Neter
# Procesando artista 549/833: Newyorkk
# Procesando artista 550/833: Niche
# Procesando artista 551/833: Nick Jonas
# Procesando artista 552/833: Nicko Altain
# Procesando artista 553/833: Nicky Jam
# Procesando artista 554/833: Nicky Romero
# Procesando artista 555/833: Nightmare
# Procesando artista 556/833: Nilakshi Neog
# Procesando artista 557/833: Nilo MC
# Procesando artista 558/833: Noelia
# Procesando artista 559/833: Noor Jehan
# Procesando artista 560/833: Nornahetta
# Procesando artista 561/833: Northern Revival
# Procesando artista 562/833: Nova
# Procesando artista 563/833: Nuclear
# Procesando artista 564/833: Nuestroctubre
# Procesando artista 565/833: Nuol
# Procesando artista 566/833: Nôa
# Procesando artista 567/833: OJM
# Procesando artista 568/833: OSV
# Procesando artista 569/833: Odair Jose
# Procesando artista 570/833: Oddó
# Procesando artista 571/833: Og Black
# Procesando artista 572/833: Oma 206
# Procesando artista 573/833: OmarCameUp
# Procesando artista 574/833: OnellFlow
# Procesando artista 575/833: Ons
# Procesando artista 576/833: Oprah
# Procesando artista 577/833: Opus V84
# Procesando artista 578/833: Order of Leviathan
# Procesando artista 579/833: Orlando Dias
# Procesando artista 580/833: Oscarcito
# Procesando artista 581/833: Our Souls
# Procesando artista 582/833: Outloud
# Procesando artista 583/833: Paasky
# Procesando artista 584/833: Pablo Und Destruktion
# Procesando artista 585/833: Paco Mc
# Procesando artista 586/833: Pagan Megalith
# Procesando artista 587/833: Panda Transport
# Procesando artista 588/833: Pandav Sunuwar
# Procesando artista 589/833: Papoose
# Procesando artista 590/833: Paramba
# Procesando artista 591/833: Pastor Troy
# Procesando artista 592/833: Patron
# Procesando artista 593/833: Pawan Singh
# Procesando artista 594/833: Payaso
# Procesando artista 595/833: Peculate
# Procesando artista 596/833: Peppino Di Capri
# Procesando artista 597/833: Perreke
# Procesando artista 598/833: Pescozada
# Procesando artista 599/833: Philippe Katerine
# Procesando artista 600/833: Phoenix Jauman
# Procesando artista 601/833: Picco
# Procesando artista 602/833: Pimpin Win
# Procesando artista 603/833: Pimpton
# Procesando artista 604/833: Piraña
# Procesando artista 605/833: Pit Bailay
# Procesando artista 606/833: Planet Asia
# Procesando artista 607/833: Plutony
# Procesando artista 608/833: Point Blank
# Procesando artista 609/833: Prajoth Dsa
# Procesando artista 610/833: Prakash Mali Mehandwas
# Procesando artista 611/833: Pramod Premi Yadav
# Procesando artista 612/833: Prem Raja Mahat
# Procesando artista 613/833: Presence
# Procesando artista 614/833: Priyani
# Procesando artista 615/833: Proksima
# Procesando artista 616/833: Prometheus
# Procesando artista 617/833: Provo
# Procesando artista 618/833: Psalms for the Dead Sun
# Procesando artista 619/833: Purple Light
# Procesando artista 620/833: Putrid Pile
# Procesando artista 621/833: Pérez Prado
# Procesando artista 622/833: QVXNO
# Procesando artista 623/833: Quang Linh
# Procesando artista 624/833: R1 La Esencia
# Procesando artista 625/833: RND
# Procesando artista 626/833: Radojka Sverko
# Procesando artista 627/833: Rajesh Payal Rai
# Procesando artista 628/833: Raju Rawal
# Procesando artista 629/833: Rampart
# Procesando artista 630/833: Rauni Pekkala
# Procesando artista 631/833: Ray Garcia
# Procesando artista 632/833: Raykel
# Procesando artista 633/833: Real Deal
# Procesando artista 634/833: Reflection
# Procesando artista 635/833: Reidar Bøe
# Procesando artista 636/833: Reincarnation
# Procesando artista 637/833: Remedy
# Procesando artista 638/833: Renato Beltrão
# Procesando artista 639/833: Reykon
# Procesando artista 640/833: Rich
# Procesando artista 641/833: Rico Fartkawski
# Procesando artista 642/833: Ridho Ramon
# Procesando artista 643/833: Rita Drangsholt
# Procesando artista 644/833: Ritesh Pandey
# Procesando artista 645/833: Riça
# Procesando artista 646/833: Roberto Limon
# Procesando artista 647/833: Roberto Scaglioni
# Procesando artista 648/833: Rocío Jurado
# Procesando artista 649/833: Rone
# Procesando artista 650/833: Ronnie Biggs
# Procesando artista 651/833: Roy Acuff
# Procesando artista 652/833: Royce Da 5'9"
# Procesando artista 653/833: Royce Wood Junior
# Procesando artista 654/833: Rudolf Cortés
# Procesando artista 655/833: Ruger 9
# Procesando artista 656/833: Russian Red
# Procesando artista 657/833: Ruxe Ruxe
# Procesando artista 658/833: Ryan Anthony
# Procesando artista 659/833: Rydah J. Klyde
# Procesando artista 660/833: SK (Sklerati Kronici)
# Procesando artista 661/833: SONDRUM
# Procesando artista 662/833: STXXCH
# Procesando artista 663/833: Sacrament
# Procesando artista 664/833: Salvation
# Procesando artista 665/833: Santi Balmes
# Procesando artista 666/833: Saphuan
# Procesando artista 667/833: Sarala Gauchan
# Procesando artista 668/833: Sardar Ali Takkar
# Procesando artista 669/833: Saro
# Procesando artista 670/833: Sashi
# Procesando artista 671/833: Savage Machine
# Procesando artista 672/833: Scala Mercalli
# Procesando artista 673/833: Scila
# Procesando artista 674/833: Screaming Condors
# Procesando artista 675/833: Scylla
# Procesando artista 676/833: Seax
# Procesando artista 677/833: Sergio Dalma
# Procesando artista 678/833: Serpentor
# Procesando artista 679/833: Servando & Florentino
# Procesando artista 680/833: Seven Stories High
# Procesando artista 681/833: Shahab Ramezan
# Procesando artista 682/833: Shaifer
# Procesando artista 683/833: Shane Tripp
# Procesando artista 684/833: Shilpa Rao
# Procesando artista 685/833: Show Me Wolves
# Procesando artista 686/833: Silky Criss
# Procesando artista 687/833: Sistema Negro
# Procesando artista 688/833: Sixto Rein
# Procesando artista 689/833: Sky Crypt
# Procesando artista 690/833: Smigg Dirtee
# Procesando artista 691/833: Sniglabandið
# Procesando artista 692/833: Sniper SP
# Procesando artista 693/833: Snoop Dogg
# Procesando artista 694/833: Snorri Helgason
# Procesando artista 695/833: Sonny & Vaech
# Procesando artista 696/833: Sonny Bo
# Procesando artista 697/833: Soraya
# Procesando artista 698/833: Soriano
# Procesando artista 699/833: Sou El Flotador
# Procesando artista 700/833: SoundGate
# Procesando artista 701/833: South Park Mexican
# Procesando artista 702/833: Spice 1
# Procesando artista 703/833: Squalee Pope
# Procesando artista 704/833: Standvast
# Procesando artista 705/833: Stardown
# Procesando artista 706/833: Stefania Rares
# Procesando artista 707/833: Steve Loc
# Procesando artista 708/833: Stink
# Procesando artista 709/833: Stonewall Jackson
# Procesando artista 710/833: Stratford
# Procesando artista 711/833: Success
# Procesando artista 712/833: Sudar Shrestha
# Procesando artista 713/833: Suez
# Procesando artista 714/833: Suicide Syndicate
# Procesando artista 715/833: Sumon
# Procesando artista 716/833: Sunita subba
# Procesando artista 717/833: Sur Ellz
# Procesando artista 718/833: Suspiral
# Procesando artista 719/833: Suzanne Prentice
# Procesando artista 720/833: Swim to Drown
# Procesando artista 721/833: Symptom
# Procesando artista 722/833: Systraskap
# Procesando artista 723/833: São Nunca
# Procesando artista 724/833: TJ Hickey
# Procesando artista 725/833: TSAR
# Procesando artista 726/833: Tahnee Matthiesen
# Procesando artista 727/833: Taka Minamino
# Procesando artista 728/833: Tara Thapa
# Procesando artista 729/833: Tarali Sarma
# Procesando artista 730/833: Tayno
# Procesando artista 731/833: Tayyib Ali
# Procesando artista 732/833: Taz
# Procesando artista 733/833: Tejal Thakor
# Procesando artista 734/833: Tempo
# Procesando artista 735/833: Terrier
# Procesando artista 736/833: The Butcher's Rodeo
# Procesando artista 737/833: The Canyon Observer
# Procesando artista 738/833: The Franks Daredevils
# Procesando artista 739/833: The Idyll's End
# Procesando artista 740/833: The Killing Hours
# Procesando artista 741/833: The Muteflutes
# Procesando artista 742/833: The Noise
# Procesando artista 743/833: The Prozacs
# Procesando artista 744/833: The Rising
# Procesando artista 745/833: The Vamps
# Procesando artista 746/833: The White Shadow
# Procesando artista 747/833: Theosophy
# Procesando artista 748/833: Thomas Arya
# Procesando artista 749/833: Tigertailz
# Procesando artista 750/833: Tiho Orlić
# Procesando artista 751/833: Timbaland
# Procesando artista 752/833: Tinez
# Procesando artista 753/833: Toralf Tollefsen
# Procesando artista 754/833: Torkel T
# Procesando artista 755/833: Trae Tha Truth
# Procesando artista 756/833: Trankei Republic
# Procesando artista 757/833: Travis Matte and the Kingpins
# Procesando artista 758/833: Trel Blaze
# Procesando artista 759/833: Trez3
# Procesando artista 760/833: Trille
# Procesando artista 761/833: Tristan Casara
# Procesando artista 762/833: Trío Martino
# Procesando artista 763/833: Turk
# Procesando artista 764/833: Tutan Come On
# Procesando artista 765/833: Udit Narayan
# Procesando artista 766/833: Ugo Angelito
# Procesando artista 767/833: Ulises
# Procesando artista 768/833: UnderWHAT?
# Procesando artista 769/833: Upon Shadows
# Procesando artista 770/833: Urheimat
# Procesando artista 771/833: UshaKiran Adhikari
# Procesando artista 772/833: Vaech
# Procesando artista 773/833: Valeriy Syutkin
# Procesando artista 774/833: Vanadium
# Procesando artista 775/833: Varry Brava
# Procesando artista 776/833: Vasilica Dinu
# Procesando artista 777/833: Veli Sahiti
# Procesando artista 778/833: Vertical
# Procesando artista 779/833: Vice Vukov
# Procesando artista 780/833: Victor Muñoz
# Procesando artista 781/833: Vinicio Capossela
# Procesando artista 782/833: Vinod Rathod
# Procesando artista 783/833: Viron
# Procesando artista 784/833: Vulto.
# Procesando artista 785/833: Václav Neckář
# Procesando artista 786/833: W&W
# Procesando artista 787/833: Watussi
# Procesando artista 788/833: Waze
# Procesando artista 789/833: Webb Pierce
# Procesando artista 790/833: Wende
# Procesando artista 791/833: Were-vana
# Procesando artista 792/833: Whythre
# Procesando artista 793/833: Wild Chain
# Procesando artista 794/833: Wild Dogs
# Procesando artista 795/833: Wisin
# Procesando artista 796/833: Xerión
# Procesando artista 797/833: Y.M. Da Kidd
# Procesando artista 798/833: Yanka
# Procesando artista 799/833: Yash Kumar
# Procesando artista 800/833: Yaves
# Procesando artista 801/833: Yggdrassil
# Procesando artista 802/833: Yo Gotti
# Procesando artista 803/833: Yoherly
# Procesando artista 804/833: Yoi Carrera
# Procesando artista 805/833: Young Lyxx
# Procesando artista 806/833: Young Pô
# Procesando artista 807/833: YourMCAdmin
# Procesando artista 808/833: Yukta Gurung
# Procesando artista 809/833: Zakaz
# Procesando artista 810/833: Zargof
# Procesando artista 811/833: Zemlyane
# Procesando artista 812/833: Zet Legacy
# Procesando artista 813/833: Zion
# Procesando artista 814/833: Zubaida Khanum
# Procesando artista 815/833: Zubeen Garg
# Procesando artista 816/833: Zulu IMG
# Procesando artista 817/833: area3
# Procesando artista 818/833: espiritusanto
# Procesando artista 819/833: filous
# Procesando artista 820/833: fizzytoofab
# Procesando artista 821/833: ghost/\/ghoul
# Procesando artista 822/833: hi-ker
# Procesando artista 823/833: Ángel Franco
# Procesando artista 824/833: Ánh Tuyết
# Procesando artista 825/833: Đặng Thế Luân
# Procesando artista 826/833: Галина Журавлёва
# Procesando artista 827/833: Дюха
# Procesando artista 828/833: Зеркальный лабиринт
# Procesando artista 829/833: Мэныч
# Procesando artista 830/833: Николина Чакърдъкова
# Procesando artista 831/833: Тима Черный
# Procesando artista 832/833: 句潤
# Procesando artista 833/833: 坡上村樂隊
# ✅ Guardado: lastfm_datos.csv (803 artistas)
# ✅ Proceso de Last.fm completado
# 💾 Insertando todos los datos en MySQL...
# 🎤 Insertando artistas en MySQL...
# 🔗 Conectando con MySQL...
# ✅ Conexión establecida: <mysql.connector.connection_cext.CMySQLConnection object at 0x000001E2E534F860>
# Base de datos activa: ('proyecto_grupal_mod_2',)
# ✅ Artistas insertados en MySQL correctamente
# 🎵 Insertando canciones en MySQL...
# 🔗 Conectando con MySQL...
# ✅ Conexión establecida: <mysql.connector.connection_cext.CMySQLConnection object at 0x000001E2E69FAFC0>
# Base de datos activa: ('proyecto_grupal_mod_2',)
# ✅ Canciones insertadas en MySQL correctamente
# ✅ Todos los datos insertados en MySQL
# ✅ ¡Todo terminado con MySQL!

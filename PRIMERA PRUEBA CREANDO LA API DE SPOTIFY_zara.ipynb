# %%
import requests
import base64

# Configura tus credenciales
client_id = "9beba5ec7f124f4282d3625eecb0339f"
client_secret = "c6501c7f4217420095f22bef5dfed7b9"

# Codifica credenciales en Base64
credentials = f"{client_id}:{client_secret}"
credentials_b64 = base64.b64encode(credentials.encode()).decode()

# Solicita token
url = "https://accounts.spotify.com/api/token"
headers = {
    "Authorization": f"Basic {credentials_b64}",
    "Content-Type": "application/x-www-form-urlencoded"
}
data = {"grant_type": "client_credentials"}

response = requests.post(url, headers=headers, data=data)
token = response.json()["access_token"]

# %%
pip install spotipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\SOL\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy

# Configura credenciales
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id="9beba5ec7f124f4282d3625eecb0339f",
    client_secret="c6501c7f4217420095f22bef5dfed7b9"
))

# Buscar artistas
results = sp.search(q='bad bunny', limit=5, type='artist')
for artist in results['artists']['items']:
    print(artist['name'], "- Popularidad:", artist['popularity'])
# Out:
# Bad Bunny - Popularidad: 100
# Mora - Popularidad: 87
# DJ BAD BUNNY - Popularidad: 32
# Myke Towers - Popularidad: 89
# Bad Bunny Chapin - Popularidad: 10

# %%
datos = sp.search(q='genre: metal, year: 2020,', type ='track', limit=50, offset =0)

# %%
datos.keys()
# Out:
# dict_keys(['tracks'])

# %%
datos['tracks'].keys()
# Out:
# dict_keys(['href', 'limit', 'next', 'offset', 'previous', 'total', 'items'])

# %%
datos['tracks']['items'][1]
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6yAMRosx47X5w8mgH5qymJ'},
#     'href': 'https://api.spotify.com/v1/artists/6yAMRosx47X5w8mgH5qymJ',
#     'id': '6yAMRosx47X5w8mgH5qymJ',
#     'name': 'Sons of Aguirre',
#     'type': 'artist',
#     'uri': 'spotify:artist:6yAMRosx47X5w8mgH5qymJ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4xYWwmYOOQLNfkvk4ll3Gg'},
#     'href': 'https://api.spotify.com/v1/artists/4xYWwmYOOQLNfkvk4ll3Gg',
#     'id': '4xYWwmYOOQLNfkvk4ll3Gg',
#     'name': 'Scila',
#     'type': 'artist',
#     'uri': 'spotify:artist:4xYWwmYOOQLNfkvk4ll3Gg'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
# ...

# %%
datos['tracks']['items'][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1RWk8RsDoNhQ5J3DPXz5AC'},
#     'href': 'https://api.spotify.com/v1/artists/1RWk8RsDoNhQ5J3DPXz5AC',
#     'id': '1RWk8RsDoNhQ5J3DPXz5AC',
#     'name': 'Knox Hill',
#     'type': 'artist',
#     'uri': 'spotify:artist:1RWk8RsDoNhQ5J3DPXz5AC'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
# ...

# %%
print(datos.keys())
# Out:
# dict_keys(['tracks'])

# %% [markdown]
# Datos que buscar: artista, género*, tipo (album o canción), nombre, año de lanzamiento*
#
# *Comentario género y año de lanzamiento: la información del género de la canción no está explicitamente mencionado en la info dentro de items. Es info que ya tenemos (la búsqueda establece que buscamos un género determinado), pero habría que ver si para tener los datos como tal, habría que complementar los datos de spotify con los de last.fm. Ocurre lo mismo con año de lanzamiento (parece que los datos de spoti solo incluyen el año de lanzamiento del álbum al que pertenece la canción, pero no el año de lanzamiento de la canción en sí)

# %%
# datos que buscar: artista, género*, tipo (album o canción), nombre, año de lanzamiento*
# *Comentario género y año de lanzamiento: la información del género de la canción no está explicitamente mencionada en la info dentro de items. Es info que ya tenemos (la búsqueda establece que buscamos un género determinado), pero habría que ver si para tener los datos como tal, habría que complementar los datos de spotify con los de last.fm. Ocurre lo mismo con año de lanzamiento (pafrece que los datos de spoti solo incluyen el año de lanzamiento del álbum al que pertenece la canción, pero no el año de lanzamiento de la canción en sí)

# %%
datos['tracks']['items'][0].keys() ## aquí identificamos las keys de la primera canción
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %% [markdown]
# 1. Nombre de la canción

# %%
cancion1 = datos['tracks']['items'][0]['name'] # Aquí hemos logrado llegar al nombre de la primera canción de las 50 a las que hemos accedido a través de la búsqueda. Hemos guardado el dato en una var (cancion1).
print(cancion1)
# Out:
# Like It Fast

# %% [markdown]
# 1. Arstista

# %%
datos['tracks']['items'][0]["artists"] ## aquí vemos que el valor de la clave "artists" es una lista que contiene dos diccionarios (son dos porque la canción es una colaboración entre dos artistas)
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1RWk8RsDoNhQ5J3DPXz5AC'},
#   'href': 'https://api.spotify.com/v1/artists/1RWk8RsDoNhQ5J3DPXz5AC',
#   'id': '1RWk8RsDoNhQ5J3DPXz5AC',
#   'name': 'Knox Hill',
#   'type': 'artist',
#   'uri': 'spotify:artist:1RWk8RsDoNhQ5J3DPXz5AC'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1WIHbvNZTybCVHFMbzuGJo'},
#   'href': 'https://api.spotify.com/v1/artists/1WIHbvNZTybCVHFMbzuGJo',
#   'id': '1WIHbvNZTybCVHFMbzuGJo',
#   'name': 'Crypt',
#   'type': 'artist',
#   'uri': 'spotify:artist:1WIHbvNZTybCVHFMbzuGJo'}]

# %%
datos['tracks']['items'][0]["artists"][0] # llegamos a la información sobre el primer artista de esta lista
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/1RWk8RsDoNhQ5J3DPXz5AC'},
#  'href': 'https://api.spotify.com/v1/artists/1RWk8RsDoNhQ5J3DPXz5AC',
#  'id': '1RWk8RsDoNhQ5J3DPXz5AC',
#  'name': 'Knox Hill',
#  'type': 'artist',
#  'uri': 'spotify:artist:1RWk8RsDoNhQ5J3DPXz5AC'}

# %%
datos['tracks']['items'][0]["artists"][0]["name"] # Aquí nos devuelve el nombre del primer artista
# Out:
# 'Knox Hill'

# %%
datos['tracks']['items'][0]["artists"][1] # llegamos a la información sobre el segundo artista de esta lista
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/1WIHbvNZTybCVHFMbzuGJo'},
#  'href': 'https://api.spotify.com/v1/artists/1WIHbvNZTybCVHFMbzuGJo',
#  'id': '1WIHbvNZTybCVHFMbzuGJo',
#  'name': 'Crypt',
#  'type': 'artist',
#  'uri': 'spotify:artist:1WIHbvNZTybCVHFMbzuGJo'}

# %%
datos['tracks']['items'][0]["artists"][1]["name"] # Aquí nos devuelve el nombre del segundo artista
# Out:
# 'Crypt'

# %% [markdown]
# 3. Tipo (canción o album)

# %%
datos['tracks']['items'][0]["type"] # No estoy segura de que estemos buscando esta info o lo que pone en album_type (ver abajo)
# Out:
# 'track'

# %%
datos['tracks']['items'][0]["album"] # vemos que dentro de la clave "album" aparece un dict con una primera clave album_type
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1RWk8RsDoNhQ5J3DPXz5AC'},
#    'href': 'https://api.spotify.com/v1/artists/1RWk8RsDoNhQ5J3DPXz5AC',
#    'id': '1RWk8RsDoNhQ5J3DPXz5AC',
#    'name': 'Knox Hill',
#    'type': 'artist',
#    'uri': 'spotify:artist:1RWk8RsDoNhQ5J3DPXz5AC'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
# ...

# %%
datos['tracks']['items'][0]["album"]["album_type"] # aquí accedemos directamente en la info de la clave "album_type". Por lo visto, los valores pueden ser "single" o "album".
# Out:
# 'album'

# %% [markdown]
# 4. Fecha de lanzamiento
#
# Si la canción forma parte de un álbum (de varios temas) → será la fecha del álbum
#
# Si es un single (álbum con solo 1 canción, como en muchos casos actuales) → será también la fecha de esa canción

# %%
datos['tracks']['items'][0]["album"]["release_date"]
# Out:
# '2020-11-27'

# %%
# Código del archivo truquito_spotify de César:

for i in range(2020, 2026):
    q=f"genre:rock, year:{i}"
    print(q)
# Out:
# genre:rock, year:2020
# genre:rock, year:2021
# genre:rock, year:2022
# genre:rock, year:2023
# genre:rock, year:2024
# genre:rock, year:2025
